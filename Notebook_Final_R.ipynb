# %% [markdown]
# # Packages installation and libraries loading

# %%
#setwd("/Users/leonardo/Desktop/SM4HDD")
rm(list=ls())

# 1) PACKAGES INSTALLATION AND LIBRARIES LOADING

# Install required package
if (!require(dplyr)) {
  install.packages("dplyr")
}

if (!require(stringr)) {
  install.packages("stringr")
}

if (!require(ggplot2)) {
  install.packages("ggplot2")
}

if (!require(maps)) {
  install.packages("maps")
}

if (!require(dplyr)) {
  install.packages("dplyr")
}

if (!require(viridis)) {
  install.packages("viridis")
}

if (!require(caret)) {
  install.packages("caret")
}

if (!require(lattice)) {
  install.packages("lattice")
}

if (!require(bestglm)) {
  install.packages("bestglm")
}

if (!require(glmnet)) {
  install.packages("glmnet")
}

if (!require(GGally)) {
  install.packages("GGally")
}

if (!require(gglasso)) {
  install.packages("gglasso")
}

if (!requireNamespace("sparseSVM", quietly = TRUE)) {
  install.packages("sparseSVM")
}

if (!require(genlasso)) {
  install.packages("genlasso")
}


if (!require(genlasso)) {
  install.packages("genlasso")
}
install.packages("remotes")
remotes::install_github("yixuan/ADMM")


# Load required libraries


#rm(list = ls())

library(ADMM)

# Load required libraries
library(ggplot2)
library(maps)
library(dplyr)
library(viridis)
library(stringr)
library(caret)
library(lattice)
library(bestglm)
library(glmnet)
library(Matrix)
library(GGally)
library(gglasso)
library(sparseSVM)
library(genlasso)
library(genlasso)
# Out:
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: stringr
#
# Loading required package: ggplot2
#
# Loading required package: maps
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘maps’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: viridis
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘viridis’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘gridExtra’
#
#
# Loading required package: caret
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘caret’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘listenv’, ‘parallelly’, ‘future’, ‘globals’, ‘shape’, ‘future.apply’, ‘numDeriv’, ‘progressr’, ‘SQUAREM’, ‘diagram’, ‘lava’, ‘prodlim’, ‘proxy’, ‘iterators’, ‘Rcpp’, ‘clock’, ‘gower’, ‘hardhat’, ‘ipred’, ‘timeDate’, ‘e1071’, ‘foreach’, ‘ModelMetrics’, ‘plyr’, ‘pROC’, ‘recipes’, ‘reshape2’
#
#
# Loading required package: lattice
#
# Loading required package: bestglm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘bestglm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘RcppEigen’, ‘leaps’, ‘glmnet’, ‘grpreg’, ‘pls’
#
#
# Loading required package: glmnet
#
# Loading required package: Matrix
#
# Loaded glmnet 4.1-8
#
# Loading required package: GGally
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘GGally’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘labelled’, ‘broom.helpers’, ‘patchwork’, ‘ggstats’
#
#
# Loading required package: gglasso
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘gglasso’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: genlasso
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘genlasso’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘igraph’
#
#
# Loading required package: genlasso
#
# Loading required package: igraph
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     as_data_frame, groups, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Downloading GitHub repo yixuan/ADMM@HEAD
# isoband (0.2.6 -> 0.2.7) [CRAN]
# Installing 1 packages: isoband
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/tmp/RtmpbWT6Qj/remotesbc41b694db/yixuan-ADMM-7a60bff/DESCRIPTION’ ... OK
# * preparing ‘ADMM’:
# * checking DESCRIPTION meta-information ... OK
# * cleaning src
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# * building ‘ADMM_1.0.tar.gz’
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: viridisLite
#
#
# Attaching package: ‘viridis’
#
#
# The following object is masked from ‘package:maps’:
#
#     unemp
#
#
# Loading required package: leaps
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# # Dataset

# %%
data <- read.csv("/content/Swarm_Behaviour.csv")
# Clearing the data: in the train set there are some NAs
data <- na.omit(data)
dim(data)

# change some data types
sapply(data, class)
data <- as.data.frame(apply(data, 2, as.numeric))  # Convert all variable types to numeric
sapply(data, class)                                # Print classes of all colums
# Out:
# [1] 23309  2401
#              x1              y1           xVel1           yVel1             xA1
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             yA1             xS1             yS1             xC1             yC1
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            nAC1             nS1              x2              y2           xVel2
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#           yVel2             xA2             yA2             xS2             yS2
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             xC2             yC2            nAC2             nS2              x3
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#              y3           xVel3           yVel3             xA3             yA3
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             xS3             yS3             xC3             yC3            nAC3
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#             nS3              x4              y4           xVel4           yVel4
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#             xA4             yA4             xS4             yS4             xC4
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             yC4            nAC4             nS4              x5              y5
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#           xVel5           yVel5             xA5             yA5             xS5
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             yS5             xC5             yC5            nAC5             nS5
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#              x6              y6           xVel6           yVel6             xA6
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             yA6             xS6             yS6             xC6             yC6
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            nAC6             nS6              x7              y7           xVel7
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#           yVel7             xA7             yA7             xS7             yS7
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             xC7             yC7            nAC7             nS7              x8
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#              y8           xVel8           yVel8             xA8             yA8
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             xS8             yS8             xC8             yC8            nAC8
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#             nS8              x9              y9           xVel9           yVel9
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#             xA9             yA9             xS9             yS9             xC9
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#             yC9            nAC9             nS9             x10             y10
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel10          yVel10            xA10            yA10            xS10
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS10            xC10            yC10           nAC10            nS10
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x11             y11          xVel11          yVel11            xA11
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA11            xS11            yS11            xC11            yC11
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC11            nS11             x12             y12          xVel12
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel12            xA12            yA12            xS12            yS12
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC12            yC12           nAC12            nS12             x13
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y13          xVel13          yVel13            xA13            yA13
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS13            yS13            xC13            yC13           nAC13
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS13             x14             y14          xVel14          yVel14
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA14            yA14            xS14            yS14            xC14
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC14           nAC14            nS14             x15             y15
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel15          yVel15            xA15            yA15            xS15
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS15            xC15            yC15           nAC15            nS15
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x16             y16          xVel16          yVel16            xA16
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA16            xS16            yS16            xC16            yC16
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC16            nS16             x17             y17          xVel17
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel17            xA17            yA17            xS17            yS17
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC17            yC17           nAC17            nS17             x18
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y18          xVel18          yVel18            xA18            yA18
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS18            yS18            xC18            yC18           nAC18
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS18             x19             y19          xVel19          yVel19
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA19            yA19            xS19            yS19            xC19
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC19           nAC19            nS19             x20             y20
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel20          yVel20            xA20            yA20            xS20
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS20            xC20            yC20           nAC20            nS20
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x21             y21          xVel21          yVel21            xA21
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA21            xS21            yS21            xC21            yC21
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC21            nS21             x22             y22          xVel22
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel22            xA22            yA22            xS22            yS22
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC22            yC22           nAC22            nS22             x23
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y23          xVel23          yVel23            xA23            yA23
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS23            yS23            xC23            yC23           nAC23
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS23             x24             y24          xVel24          yVel24
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA24            yA24            xS24            yS24            xC24
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC24           nAC24            nS24             x25             y25
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel25          yVel25            xA25            yA25            xS25
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS25            xC25            yC25           nAC25            nS25
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x26             y26          xVel26          yVel26            xA26
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA26            xS26            yS26            xC26            yC26
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC26            nS26             x27             y27          xVel27
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel27            xA27            yA27            xS27            yS27
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC27            yC27           nAC27            nS27             x28
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y28          xVel28          yVel28            xA28            yA28
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS28            yS28            xC28            yC28           nAC28
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS28             x29             y29          xVel29          yVel29
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA29            yA29            xS29            yS29            xC29
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC29           nAC29            nS29             x30             y30
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel30          yVel30            xA30            yA30            xS30
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS30            xC30            yC30           nAC30            nS30
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x31             y31          xVel31          yVel31            xA31
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA31            xS31            yS31            xC31            yC31
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC31            nS31             x32             y32          xVel32
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel32            xA32            yA32            xS32            yS32
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC32            yC32           nAC32            nS32             x33
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y33          xVel33          yVel33            xA33            yA33
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS33            yS33            xC33            yC33           nAC33
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS33             x34             y34          xVel34          yVel34
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA34            yA34            xS34            yS34            xC34
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC34           nAC34            nS34             x35             y35
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel35          yVel35            xA35            yA35            xS35
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS35            xC35            yC35           nAC35            nS35
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x36             y36          xVel36          yVel36            xA36
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA36            xS36            yS36            xC36            yC36
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC36            nS36             x37             y37          xVel37
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel37            xA37            yA37            xS37            yS37
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC37            yC37           nAC37            nS37             x38
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y38          xVel38          yVel38            xA38            yA38
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS38            yS38            xC38            yC38           nAC38
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS38             x39             y39          xVel39          yVel39
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA39            yA39            xS39            yS39            xC39
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC39           nAC39            nS39             x40             y40
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel40          yVel40            xA40            yA40            xS40
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS40            xC40            yC40           nAC40            nS40
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x41             y41          xVel41          yVel41            xA41
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA41            xS41            yS41            xC41            yC41
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC41            nS41             x42             y42          xVel42
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel42            xA42            yA42            xS42            yS42
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC42            yC42           nAC42            nS42             x43
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y43          xVel43          yVel43            xA43            yA43
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS43            yS43            xC43            yC43           nAC43
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS43             x44             y44          xVel44          yVel44
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA44            yA44            xS44            yS44            xC44
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC44           nAC44            nS44             x45             y45
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel45          yVel45            xA45            yA45            xS45
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS45            xC45            yC45           nAC45            nS45
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x46             y46          xVel46          yVel46            xA46
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA46            xS46            yS46            xC46            yC46
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC46            nS46             x47             y47          xVel47
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel47            xA47            yA47            xS47            yS47
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC47            yC47           nAC47            nS47             x48
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y48          xVel48          yVel48            xA48            yA48
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS48            yS48            xC48            yC48           nAC48
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS48             x49             y49          xVel49          yVel49
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA49            yA49            xS49            yS49            xC49
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC49           nAC49            nS49             x50             y50
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel50          yVel50            xA50            yA50            xS50
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS50            xC50            yC50           nAC50            nS50
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x51             y51          xVel51          yVel51            xA51
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA51            xS51            yS51            xC51            yC51
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC51            nS51             x52             y52          xVel52
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel52            xA52            yA52            xS52            yS52
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC52            yC52           nAC52            nS52             x53
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y53          xVel53          yVel53            xA53            yA53
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS53            yS53            xC53            yC53           nAC53
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS53             x54             y54          xVel54          yVel54
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA54            yA54            xS54            yS54            xC54
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC54           nAC54            nS54             x55             y55
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel55          yVel55            xA55            yA55            xS55
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS55            xC55            yC55           nAC55            nS55
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x56             y56          xVel56          yVel56            xA56
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA56            xS56            yS56            xC56            yC56
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC56            nS56             x57             y57          xVel57
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel57            xA57            yA57            xS57            yS57
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC57            yC57           nAC57            nS57             x58
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y58          xVel58          yVel58            xA58            yA58
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS58            yS58            xC58            yC58           nAC58
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS58             x59             y59          xVel59          yVel59
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA59            yA59            xS59            yS59            xC59
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC59           nAC59            nS59             x60             y60
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel60          yVel60            xA60            yA60            xS60
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS60            xC60            yC60           nAC60            nS60
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x61             y61          xVel61          yVel61            xA61
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA61            xS61            yS61            xC61            yC61
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC61            nS61             x62             y62          xVel62
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel62            xA62            yA62            xS62            yS62
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC62            yC62           nAC62            nS62             x63
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y63          xVel63          yVel63            xA63            yA63
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS63            yS63            xC63            yC63           nAC63
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS63             x64             y64          xVel64          yVel64
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA64            yA64            xS64            yS64            xC64
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC64           nAC64            nS64             x65             y65
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel65          yVel65            xA65            yA65            xS65
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS65            xC65            yC65           nAC65            nS65
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x66             y66          xVel66          yVel66            xA66
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA66            xS66            yS66            xC66            yC66
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC66            nS66             x67             y67          xVel67
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel67            xA67            yA67            xS67            yS67
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC67            yC67           nAC67            nS67             x68
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y68          xVel68          yVel68            xA68            yA68
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS68            yS68            xC68            yC68           nAC68
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS68             x69             y69          xVel69          yVel69
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA69            yA69            xS69            yS69            xC69
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC69           nAC69            nS69             x70             y70
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel70          yVel70            xA70            yA70            xS70
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS70            xC70            yC70           nAC70            nS70
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x71             y71          xVel71          yVel71            xA71
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA71            xS71            yS71            xC71            yC71
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC71            nS71             x72             y72          xVel72
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel72            xA72            yA72            xS72            yS72
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC72            yC72           nAC72            nS72             x73
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y73          xVel73          yVel73            xA73            yA73
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS73            yS73            xC73            yC73           nAC73
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS73             x74             y74          xVel74          yVel74
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA74            yA74            xS74            yS74            xC74
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC74           nAC74            nS74             x75             y75
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel75          yVel75            xA75            yA75            xS75
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS75            xC75            yC75           nAC75            nS75
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x76             y76          xVel76          yVel76            xA76
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA76            xS76            yS76            xC76            yC76
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC76            nS76             x77             y77          xVel77
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel77            xA77            yA77            xS77            yS77
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC77            yC77           nAC77            nS77             x78
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y78          xVel78          yVel78            xA78            yA78
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS78            yS78            xC78            yC78           nAC78
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS78             x79             y79          xVel79          yVel79
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA79            yA79            xS79            yS79            xC79
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC79           nAC79            nS79             x80             y80
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel80          yVel80            xA80            yA80            xS80
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS80            xC80            yC80           nAC80            nS80
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x81             y81          xVel81          yVel81            xA81
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA81            xS81            yS81            xC81            yC81
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC81            nS81             x82             y82          xVel82
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel82            xA82            yA82            xS82            yS82
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC82            yC82           nAC82            nS82             x83
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y83          xVel83          yVel83            xA83            yA83
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS83            yS83            xC83            yC83           nAC83
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS83             x84             y84          xVel84          yVel84
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA84            yA84            xS84            yS84            xC84
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC84           nAC84            nS84             x85             y85
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel85          yVel85            xA85            yA85            xS85
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS85            xC85            yC85           nAC85            nS85
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x86             y86          xVel86          yVel86            xA86
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA86            xS86            yS86            xC86            yC86
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC86            nS86             x87             y87          xVel87
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel87            xA87            yA87            xS87            yS87
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC87            yC87           nAC87            nS87             x88
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y88          xVel88          yVel88            xA88            yA88
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS88            yS88            xC88            yC88           nAC88
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS88             x89             y89          xVel89          yVel89
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA89            yA89            xS89            yS89            xC89
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC89           nAC89            nS89             x90             y90
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel90          yVel90            xA90            yA90            xS90
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS90            xC90            yC90           nAC90            nS90
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x91             y91          xVel91          yVel91            xA91
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA91            xS91            yS91            xC91            yC91
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC91            nS91             x92             y92          xVel92
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel92            xA92            yA92            xS92            yS92
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC92            yC92           nAC92            nS92             x93
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y93          xVel93          yVel93            xA93            yA93
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS93            yS93            xC93            yC93           nAC93
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS93             x94             y94          xVel94          yVel94
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA94            yA94            xS94            yS94            xC94
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC94           nAC94            nS94             x95             y95
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#          xVel95          yVel95            xA95            yA95            xS95
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yS95            xC95            yC95           nAC95            nS95
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#             x96             y96          xVel96          yVel96            xA96
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yA96            xS96            yS96            xC96            yC96
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nAC96            nS96             x97             y97          xVel97
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#          yVel97            xA97            yA97            xS97            yS97
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xC97            yC97           nAC97            nS97             x98
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#             y98          xVel98          yVel98            xA98            yA98
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            xS98            yS98            xC98            yC98           nAC98
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#            nS98             x99             y99          xVel99          yVel99
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#            xA99            yA99            xS99            yS99            xC99
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            yC99           nAC99            nS99            x100            y100
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#         xVel100         yVel100           xA100           yA100           xS100
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS100           xC100           yC100          nAC100           nS100
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#            x101            y101         xVel101         yVel101           xA101
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA101           xS101           yS101           xC101           yC101
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC101           nS101            x102            y102         xVel102
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#         yVel102           xA102           yA102           xS102           yS102
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC102           yC102          nAC102           nS102            x103
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#            y103         xVel103         yVel103           xA103           yA103
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS103           yS103           xC103           yC103          nAC103
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#           nS103            x104            y104         xVel104         yVel104
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA104           yA104           xS104           yS104           xC104
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC104          nAC104           nS104            x105            y105
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#         xVel105         yVel105           xA105           yA105           xS105
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS105           xC105           yC105          nAC105           nS105
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#            x106            y106         xVel106         yVel106           xA106
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA106           xS106           yS106           xC106           yC106
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC106           nS106            x107            y107         xVel107
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#         yVel107           xA107           yA107           xS107           yS107
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC107           yC107          nAC107           nS107            x108
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#            y108         xVel108         yVel108           xA108           yA108
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS108           yS108           xC108           yC108          nAC108
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#           nS108            x109            y109         xVel109         yVel109
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA109           yA109           xS109           yS109           xC109
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC109          nAC109           nS109            x110            y110
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#         xVel110         yVel110           xA110           yA110           xS110
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS110           xC110           yC110          nAC110           nS110
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#            x111            y111         xVel111         yVel111           xA111
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA111           xS111           yS111           xC111           yC111
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC111           nS111            x112            y112         xVel112
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#         yVel112           xA112           yA112           xS112           yS112
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC112           yC112          nAC112           nS112            x113
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#            y113         xVel113         yVel113           xA113           yA113
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS113           yS113           xC113           yC113          nAC113
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#           nS113            x114            y114         xVel114         yVel114
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA114           yA114           xS114           yS114           xC114
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC114          nAC114           nS114            x115            y115
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#         xVel115         yVel115           xA115           yA115           xS115
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS115           xC115           yC115          nAC115           nS115
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#            x116            y116         xVel116         yVel116           xA116
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA116           xS116           yS116           xC116           yC116
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC116           nS116            x117            y117         xVel117
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#         yVel117           xA117           yA117           xS117           yS117
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC117           yC117          nAC117           nS117            x118
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#            y118         xVel118         yVel118           xA118           yA118
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS118           yS118           xC118           yC118          nAC118
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#           nS118            x119            y119         xVel119         yVel119
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA119           yA119           xS119           yS119           xC119
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC119          nAC119           nS119            x120            y120
#       "numeric"       "integer"       "integer"       "numeric"       "numeric"
#         xVel120         yVel120           xA120           yA120           xS120
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS120           xC120           yC120          nAC120           nS120
#       "numeric"       "numeric"       "numeric"       "integer"       "integer"
#            x121            y121         xVel121         yVel121           xA121
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA121           xS121           yS121           xC121           yC121
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC121           nS121            x122            y122         xVel122
#       "integer"       "integer"       "numeric"       "numeric"       "numeric"
#         yVel122           xA122           yA122           xS122           yS122
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC122           yC122          nAC122           nS122            x123
#       "numeric"       "numeric"       "integer"       "integer"       "numeric"
#            y123         xVel123         yVel123           xA123           yA123
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS123           yS123           xC123           yC123          nAC123
#       "numeric"       "numeric"       "numeric"       "numeric"       "integer"
#           nS123            x124            y124         xVel124         yVel124
#       "integer"       "numeric"       "numeric"       "numeric"       "numeric"
# ...
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel160         yVel160           xA160           yA160           xS160
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS160           xC160           yC160          nAC160           nS160
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x161            y161         xVel161         yVel161           xA161
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA161           xS161           yS161           xC161           yC161
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC161           nS161            x162            y162         xVel162
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel162           xA162           yA162           xS162           yS162
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC162           yC162          nAC162           nS162            x163
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y163         xVel163         yVel163           xA163           yA163
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS163           yS163           xC163           yC163          nAC163
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS163            x164            y164         xVel164         yVel164
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA164           yA164           xS164           yS164           xC164
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC164          nAC164           nS164            x165            y165
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel165         yVel165           xA165           yA165           xS165
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS165           xC165           yC165          nAC165           nS165
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x166            y166         xVel166         yVel166           xA166
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA166           xS166           yS166           xC166           yC166
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC166           nS166            x167            y167         xVel167
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel167           xA167           yA167           xS167           yS167
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC167           yC167          nAC167           nS167            x168
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y168         xVel168         yVel168           xA168           yA168
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS168           yS168           xC168           yC168          nAC168
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS168            x169            y169         xVel169         yVel169
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA169           yA169           xS169           yS169           xC169
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC169          nAC169           nS169            x170            y170
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel170         yVel170           xA170           yA170           xS170
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS170           xC170           yC170          nAC170           nS170
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x171            y171         xVel171         yVel171           xA171
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA171           xS171           yS171           xC171           yC171
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC171           nS171            x172            y172         xVel172
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel172           xA172           yA172           xS172           yS172
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC172           yC172          nAC172           nS172            x173
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y173         xVel173         yVel173           xA173           yA173
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS173           yS173           xC173           yC173          nAC173
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS173            x174            y174         xVel174         yVel174
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA174           yA174           xS174           yS174           xC174
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC174          nAC174           nS174            x175            y175
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel175         yVel175           xA175           yA175           xS175
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS175           xC175           yC175          nAC175           nS175
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x176            y176         xVel176         yVel176           xA176
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA176           xS176           yS176           xC176           yC176
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC176           nS176            x177            y177         xVel177
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel177           xA177           yA177           xS177           yS177
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC177           yC177          nAC177           nS177            x178
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y178         xVel178         yVel178           xA178           yA178
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS178           yS178           xC178           yC178          nAC178
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS178            x179            y179         xVel179         yVel179
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA179           yA179           xS179           yS179           xC179
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC179          nAC179           nS179            x180            y180
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel180         yVel180           xA180           yA180           xS180
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS180           xC180           yC180          nAC180           nS180
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x181            y181         xVel181         yVel181           xA181
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA181           xS181           yS181           xC181           yC181
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC181           nS181            x182            y182         xVel182
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel182           xA182           yA182           xS182           yS182
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC182           yC182          nAC182           nS182            x183
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y183         xVel183         yVel183           xA183           yA183
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS183           yS183           xC183           yC183          nAC183
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS183            x184            y184         xVel184         yVel184
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA184           yA184           xS184           yS184           xC184
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC184          nAC184           nS184            x185            y185
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel185         yVel185           xA185           yA185           xS185
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS185           xC185           yC185          nAC185           nS185
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x186            y186         xVel186         yVel186           xA186
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA186           xS186           yS186           xC186           yC186
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC186           nS186            x187            y187         xVel187
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel187           xA187           yA187           xS187           yS187
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC187           yC187          nAC187           nS187            x188
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y188         xVel188         yVel188           xA188           yA188
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS188           yS188           xC188           yC188          nAC188
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS188            x189            y189         xVel189         yVel189
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA189           yA189           xS189           yS189           xC189
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC189          nAC189           nS189            x190            y190
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel190         yVel190           xA190           yA190           xS190
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS190           xC190           yC190          nAC190           nS190
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x191            y191         xVel191         yVel191           xA191
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA191           xS191           yS191           xC191           yC191
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC191           nS191            x192            y192         xVel192
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel192           xA192           yA192           xS192           yS192
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC192           yC192          nAC192           nS192            x193
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y193         xVel193         yVel193           xA193           yA193
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS193           yS193           xC193           yC193          nAC193
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS193            x194            y194         xVel194         yVel194
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA194           yA194           xS194           yS194           xC194
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC194          nAC194           nS194            x195            y195
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel195         yVel195           xA195           yA195           xS195
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS195           xC195           yC195          nAC195           nS195
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            x196            y196         xVel196         yVel196           xA196
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yA196           xS196           yS196           xC196           yC196
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#          nAC196           nS196            x197            y197         xVel197
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         yVel197           xA197           yA197           xS197           yS197
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xC197           yC197          nAC197           nS197            x198
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#            y198         xVel198         yVel198           xA198           yA198
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xS198           yS198           xC198           yC198          nAC198
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           nS198            x199            y199         xVel199         yVel199
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           xA199           yA199           xS199           yS199           xC199
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yC199          nAC199           nS199            x200            y200
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#         xVel200         yVel200           xA200           yA200           xS200
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
#           yS200           xC200           yC200          nAC200           nS200
#       "numeric"       "numeric"       "numeric"       "numeric"       "numeric"
# Swarm_Behaviour
#       "numeric"

# %% [markdown]
# ## Are the classes well balanced?

# %%
table(data$Swarm_Behaviour)

# Setting seed for reproducibility
set.seed(123)

# Rebalance the classes deleting from class 0 until the classes are balanced
indices_class_0 <- which(data$Swarm_Behaviour == 0)
sampled_indices <- sample(indices_class_0, 7954)
new_class_0 <- data[sampled_indices, ]

indices_class_1 <- which(data$Swarm_Behaviour == 1)
sampled_indices1 <- sample(indices_class_1, 7954)
new_class_1 <- data[sampled_indices1, ]

data <- rbind(new_class_1, new_class_0)

# We can see now that the classes are balanced
table(data$Swarm_Behaviour)
# Out:
#     0     1
# 15355  7954
#    0    1
# 7954 7954

# %% [markdown]
# ## Train test split

# %%
# Create an index for splitting the data
index <- createDataPartition(data$Swarm_Behaviour, p = 0.1, list = FALSE)

# Create training and testing sets
train <- data[index, ]
test <- data[-index, ]

# Define X_train and y_train
X_train <- train[, !names(train) %in% "Swarm_Behaviour"]  # Exclude the column "Swarm_Behaviour"
y_train <- train$Swarm_Behaviour

# Define X_test and y_test
X_test <- test[, !names(test) %in% "Swarm_Behaviour"]
y_test <- test$Swarm_Behaviour

# Print the dimensions of the resulting sets
cat("Dimensions of Training Set:", dim(train), "\n")
cat("Dimensions of Testing Set:", dim(test), "\n")
# Out:
# Dimensions of Training Set: 1592 2401
# Dimensions of Testing Set: 14316 2401

# %% [markdown]
# Here we sample some smaller parts of our data for cross-validation, where the running time of the algorithms is too long.

# %%
# Set the desired number of observations for the subsets (extract a subset of train for the cv)
desired_size_train <- 1000

# Randomly sample the specified number of observations for training set
sample_indices_train <- sample(1:nrow(X_train), size = desired_size_train, replace = FALSE)
X_train_cv <- X_train[sample_indices_train, ]
y_train_cv <- y_train[sample_indices_train]

# Print the dimensions of the resulting subsets
cat("Dimensions of X_train_cv:", dim(X_train_cv), "\n")
cat("Dimensions of y_train_cv:", length(y_train_cv), "\n")
# Out:
# Dimensions of X_train_cv: 1000 2400
# Dimensions of y_train_cv: 1000

# %%
# Count of 1s and 0s in the training set
table_y_train <- table(y_train)
cat("Training Set - Count of 1s:", table_y_train[["1"]], "\n")
cat("Training Set - Count of 0s:", table_y_train[["0"]], "\n")

# Count of 1s and 0s in the cross-validation training set
table_y_train_cv <- table(y_train_cv)
cat("CV Training Set - Count of 1s:", table_y_train_cv[["1"]], "\n")
cat("CV Training Set - Count of 0s:", table_y_train_cv[["0"]], "\n")
# Out:
# Training Set - Count of 1s: 796
# Training Set - Count of 0s: 796
# CV Training Set - Count of 1s: 492
# CV Training Set - Count of 0s: 508

# %% [markdown]
# ## Correlations

# %%
correlations <- cor(train)

# Let's see the correlations between each feature and the class
# Extract the last column (correlation with the variable 'Swarm_behaviour')
cor_with_class <- correlations[, ncol(correlations)]

# Order the correlation values
ordered_cor <- sort(cor_with_class)

# Exclude the last element
ordered_cor <- ordered_cor[-length(ordered_cor)]

# Plot the ordered correlation values
barplot(ordered_cor, main = "Correlation with 'class'", xlab = "Features", ylab = "Correlation")
# Out:
# Plot with title “Correlation with 'class'”

# %%
# Print the tail
tail(ordered_cor)

# Get the names of the top 10 most correlated variables
top_10_vars <- names(tail(ordered_cor, 10))

# Extract the relevant columns from the training set
top_10_correlation_data <- train[, c(top_10_vars, "Swarm_Behaviour")]

# Calculate the correlation matrix for the top 10 variables
top_10_correlations <- cor(top_10_correlation_data)

# Print the correlation matrix
print(top_10_correlations)
# We can see that the correlations are between 0.60 and 0.75, so they are correlated

ggplot(train, aes(x = yVel172 , y = yVel69 , color = as.factor(Swarm_Behaviour))) +
  geom_point() +
  labs(title = "yVel172 vs yVel69",
       x = "yVel172",
       y = "yVel69",
       color = "Swarm_Behaviour")

# Create a pair plot using ggpairs
ggpairs(top_10_correlation_data)
# It does not seem good though
# Out:
#   yVel126   yVel119    yVel56   yVel131    yVel41    yVel95
# 0.4903307 0.5025039 0.5035250 0.5190072 0.5381353 0.5465866
#                   yVel176    yVel84   yVel109   yVel120   yVel126   yVel119
# yVel176         1.0000000 0.7615228 0.7102706 0.7596071 0.6850545 0.7250268
# yVel84          0.7615228 1.0000000 0.7280396 0.7281759 0.6909845 0.6986163
# yVel109         0.7102706 0.7280396 1.0000000 0.6924662 0.6648543 0.6896373
# yVel120         0.7596071 0.7281759 0.6924662 1.0000000 0.6828202 0.7040069
# yVel126         0.6850545 0.6909845 0.6648543 0.6828202 1.0000000 0.6992371
# yVel119         0.7250268 0.6986163 0.6896373 0.7040069 0.6992371 1.0000000
# yVel56          0.7268815 0.6895803 0.6659800 0.6844078 0.7142701 0.6655262
# yVel131         0.7300180 0.7671321 0.7483515 0.7321558 0.7184907 0.7454515
# yVel41          0.7494430 0.7846382 0.7273418 0.7470345 0.7010056 0.7047667
# yVel95          0.7518226 0.7168770 0.6230723 0.7091736 0.6113530 0.6773700
# Swarm_Behaviour 0.4855942 0.4875822 0.4890984 0.4891425 0.4903307 0.5025039
#                    yVel56   yVel131    yVel41    yVel95 Swarm_Behaviour
# yVel176         0.7268815 0.7300180 0.7494430 0.7518226       0.4855942
# yVel84          0.6895803 0.7671321 0.7846382 0.7168770       0.4875822
# yVel109         0.6659800 0.7483515 0.7273418 0.6230723       0.4890984
# yVel120         0.6844078 0.7321558 0.7470345 0.7091736       0.4891425
# yVel126         0.7142701 0.7184907 0.7010056 0.6113530       0.4903307
# yVel119         0.6655262 0.7454515 0.7047667 0.6773700       0.5025039
# yVel56          1.0000000 0.6849001 0.7421352 0.6776892       0.5035250
# yVel131         0.6849001 1.0000000 0.7302131 0.6639429       0.5190072
# yVel41          0.7421352 0.7302131 1.0000000 0.7032666       0.5381353
# yVel95          0.6776892 0.6639429 0.7032666 1.0000000       0.5465866
# Swarm_Behaviour 0.5035250 0.5190072 0.5381353 0.5465866       1.0000000
# plot without title
# plot without title

# %% [markdown]
# # Lasso Classifier - Linear Model

# %%
# Rename the datasets
X_cv <- X_train_cv
y_cv <- y_train_cv

# Adjust type
X_cv <- as.matrix(X_cv)
y_cv <- as.vector(y_cv)

model <- glmnet(x = X_cv, y = y_cv)
cv_results <- cv.glmnet(X_cv, y_cv, type.measure = "mse", nfolds = 10)

# Plot the graph with lambdas
plot(cv_results)
plot(model, xvar = "lambda")
# Out:
# plot without title
# plot without title

# %%
# Extract the best lambda
best_lambda <- cv_results$lambda.min

# print the best lambda
cat("The lambda min is: ", best_lambda, "\n")

# Fit the final model with the best lambda
lasso_model <- glmnet(X_train, y_train, alpha = 1, lambda = best_lambda)

# Extract coefficients for selected variables
coefficients <- coef(lasso_model, s = best_lambda)

# Count and print selected variables
selected_variables <- sum(coefficients != 0)
print(paste("Number of selected variables:", selected_variables))
# Out:
# The lambda min is:  0.02511526
# [1] "Number of selected variables: 89"

# %%
# Make predictions (replace X_test with your test set)
predictions <- predict(lasso_model, newx = as.matrix(X_test), s = best_lambda)

# Mean Squared Error
mse <- mean((predictions - y_test)^2)
print(paste("Mean Squared Error on Test Set:", mse))

# Convert predictions to binary (e.g., using a threshold)
threshold <- 0.5
binary_predictions <- ifelse(predictions > threshold, 1, 0)

conf_matrix <- table(binary_predictions, y_test)

# Calculate accuracy
accuracy <- sum(diag(conf_matrix)) / sum(conf_matrix)
print(paste("Accuracy:", accuracy))

# Precision
precision <- conf_matrix[2, 2] / sum(conf_matrix[, 2])
print(paste("Precision:", precision))

# Recall
recall <- conf_matrix[2, 2] / sum(conf_matrix[2, ])
print(paste("Recall:", recall))

# Adding headers to the confusion matrix
colnames(conf_matrix) <- c("Actual 0", "Actual 1")
rownames(conf_matrix) <- c("Predicted 0", "Predicted 1")

# Print the modified confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# [1] "Mean Squared Error on Test Set: 0.0677109855948951"
# [1] "Accuracy: 0.909960882928192"
# [1] "Precision: 0.925537859737357"
# [1] "Recall: 0.897574854355778"
# [1] "Confusion Matrix:"
#                   y_test
# binary_predictions Actual 0 Actual 1
#        Predicted 0     6402      533
#        Predicted 1      756     6625

# %%
# Get the names and coefficients of selected variables
nonzero_rows <- as.matrix(coefficients[apply(coefficients != 0, 1, any), , drop = FALSE])
variable_name <- names(which(nonzero_rows[, 1] != 0))
print(variable_name)
variable_list <- as.list(variable_name)
variable_list <- variable_list[variable_list != "(Intercept)"]

# Deleting the number at the end of the strings
for (i in seq_along(variable_list)) {
  # Extract the current variable name
  current_variable <- variable_list[[i]]

  # Remove numbers at the end of the string
  cleaned_variable <- gsub("\\d+$", "", current_variable)

  # Update the variable name in the list
  variable_list[[i]] <- cleaned_variable
}

# Assuming variable_list is a list of variable names
# Convert the list to a vector
variable_vector <- unlist(variable_list)

# Create a frequency table
variable_frequency <- table(variable_vector)

# Define the desired order for the x-axis
desired_order <- c("x", "y", "xVel", "yVel", "xA", "yA", "xS", "yS", "xC", "yC", "nAC", "nS")

# Plot the frequency histogram with specific order on the x-axis
barplot(variable_frequency[desired_order], main = "Variable Frequency Histogram", xlab = "Variable Names", ylab = "Frequency", names.arg = desired_order)
# Out:
#  [1] "(Intercept)" "xVel1"       "xVel3"       "nS4"         "xVel5"
#  [6] "xC6"         "xVel7"       "nS12"        "yC14"        "yVel19"
# [11] "x25"         "yC31"        "yVel40"      "yVel41"      "x42"
# [16] "xVel43"      "nS43"        "xC45"        "yC46"        "xC49"
# [21] "yC51"        "xC52"        "xVel53"      "nS55"        "x57"
# [26] "nS59"        "xVel63"      "x65"         "yVel65"      "xVel66"
# [31] "xVel69"      "yVel69"      "xC69"        "yC72"        "xC74"
# [36] "nS74"        "xVel85"      "yC85"        "xC94"        "yVel95"
# [41] "yC95"        "xVel96"      "xC98"        "yC98"        "xVel101"
# [46] "xVel103"     "xC105"       "xVel106"     "yC108"       "xVel109"
# [51] "yVel109"     "nS110"       "yC113"       "xC114"       "xVel115"
# [56] "xC117"       "yC117"       "yC118"       "yVel119"     "yVel120"
# [61] "x123"        "xVel125"     "yVel126"     "xVel129"     "xVel131"
# [66] "yVel131"     "yC131"       "yC132"       "xVel141"     "nS149"
# [71] "nS151"       "yVel152"     "xC154"       "xC158"       "yC163"
# [76] "nS164"       "xC168"       "yC168"       "yC171"       "yC172"
# [81] "yVel177"     "xVel179"     "xC185"       "xC189"       "nS191"
# [86] "xVel195"     "yC196"       "xVel197"     "yC198"
# Plot with title “Variable Frequency Histogram”

# %% [markdown]
# # Ridge Classifier - Linear Model

# %%
# Fit Ridge Regression Model
library(glmnet)
model <- glmnet(x = X_cv, y = y_cv, alpha = 0)  # Set alpha to 0 for ridge regression

# Cross-Validation
cv_results <- cv.glmnet(X_cv, y_cv, type.measure = "mse", nfolds = 10)

# Plot Cross-Validation Results
plot(cv_results)

# Plot Coefficient Paths
plot(model, xvar = "lambda")
# Out:
# plot without title
# plot without title

# %%
# Extract the optimal lambda value
optimal_lambda <- cv_results$lambda.min
cat("Optimal Lambda:", optimal_lambda, "\n")

# Refit the model with the optimal lambda
final_model <- glmnet(x = X_cv, y = y_cv, alpha = 0, lambda = optimal_lambda)

# Extract the best lambda
best_lambda <- cv_results$lambda.min

# Print the best lambda
cat("The lambda min is:", best_lambda, "\n")
# Out:
# Optimal Lambda: 0.02184397
# The lambda min is: 0.02184397

# %%
# Fit the final model with ridge regression and the best lambda
ridge_model <- glmnet(x = X_train, y = y_train, alpha = 0, lambda = best_lambda)

# Extract coefficients for selected variables
coefficients <- coef(ridge_model, s = best_lambda)

# Make predictions (replace X_test with your test set)
predictions <- predict(ridge_model, newx = as.matrix(X_test), s = best_lambda)

# Mean Squared Error
mse <- mean((predictions - y_test)^2)
print(paste("Mean Squared Error on Test Set:", mse))

# Convert predictions to binary (e.g., using a threshold)
threshold <- 0.5
binary_predictions <- ifelse(predictions > threshold, 1, 0)

# Calculate confusion matrix
conf_matrix <- table(binary_predictions, y_test)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# [1] "Mean Squared Error on Test Set: 5763.62240006795"
# [1] "Confusion Matrix:"
#                   y_test
# binary_predictions    0    1
#                  0 6255  739
#                  1  903 6419

# %%
# Calculate accuracy
accuracy <- sum(diag(conf_matrix)) / sum(conf_matrix)
print(paste("Accuracy:", accuracy))

# Precision
precision <- conf_matrix[2, 2] / sum(conf_matrix[, 2])
print(paste("Precision:", precision))

# Recall
recall <- conf_matrix[2, 2] / sum(conf_matrix[2, ])
print(paste("Recall:", recall))
# Out:
# [1] "Accuracy: 0.88530315730651"
# [1] "Precision: 0.896758871193071"
# [1] "Recall: 0.876673040152964"

# %% [markdown]
# # Elastic Net Classifier

# %%
# Convert data to matrix
X_train_cv <- as.matrix(X_train_cv)
X_test <- as.matrix(X_test)
y_train_cv <- as.vector(y_train_cv)
y_test <- as.vector(y_test)
X_train <- as.matrix(X_train)
y_train <- as.vector(y_train)

# Define alpha and lambda sequences for grid search
alphas <- seq(0, 1, by = 0.1)  # Set your alpha sequence
lambdas <- seq(0.001, 1, by = 0.1)  # Set your lambda sequence
# Generate a grid of all combinations of alpha and lambda
param_grid <- expand.grid(alpha = alphas, lambda = lambdas)
# Train using grid search and save the MSE values
mse_values <- matrix(NA, nrow = length(alphas), ncol = length(lambdas))

# %%
custom <- trainControl(method = "repeatedcv", number = 10, repeats = 5, verboseIter = TRUE)
set.seed(1234)
train_data_cv <- cbind.data.frame(y_train_cv, X_train_cv)
for (i in seq_len(nrow(param_grid))) {
  current_alpha <- param_grid$alpha[i]
  current_lambda <- param_grid$lambda[i]

  model <- train(
    y_train_cv ~ .,
    data = train_data_cv,
    method = 'glmnet',
    tuneGrid = data.frame(alpha = current_alpha, lambda = current_lambda),
    trControl = custom
  )
    mse_values[which(alphas == current_alpha), which(lambdas == current_lambda)] <- min(model$results$RMSE)
}
# Out:
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0, lambda=0.001
# - Fold01.Rep1: alpha=0, lambda=0.001
# + Fold02.Rep1: alpha=0, lambda=0.001
# - Fold02.Rep1: alpha=0, lambda=0.001
# + Fold03.Rep1: alpha=0, lambda=0.001
# - Fold03.Rep1: alpha=0, lambda=0.001
# + Fold04.Rep1: alpha=0, lambda=0.001
# - Fold04.Rep1: alpha=0, lambda=0.001
# + Fold05.Rep1: alpha=0, lambda=0.001
# - Fold05.Rep1: alpha=0, lambda=0.001
# + Fold06.Rep1: alpha=0, lambda=0.001
# - Fold06.Rep1: alpha=0, lambda=0.001
# + Fold07.Rep1: alpha=0, lambda=0.001
# - Fold07.Rep1: alpha=0, lambda=0.001
# + Fold08.Rep1: alpha=0, lambda=0.001
# - Fold08.Rep1: alpha=0, lambda=0.001
# + Fold09.Rep1: alpha=0, lambda=0.001
# - Fold09.Rep1: alpha=0, lambda=0.001
# + Fold10.Rep1: alpha=0, lambda=0.001
# - Fold10.Rep1: alpha=0, lambda=0.001
# + Fold01.Rep2: alpha=0, lambda=0.001
# - Fold01.Rep2: alpha=0, lambda=0.001
# + Fold02.Rep2: alpha=0, lambda=0.001
# - Fold02.Rep2: alpha=0, lambda=0.001
# + Fold03.Rep2: alpha=0, lambda=0.001
# - Fold03.Rep2: alpha=0, lambda=0.001
# + Fold04.Rep2: alpha=0, lambda=0.001
# - Fold04.Rep2: alpha=0, lambda=0.001
# + Fold05.Rep2: alpha=0, lambda=0.001
# - Fold05.Rep2: alpha=0, lambda=0.001
# + Fold06.Rep2: alpha=0, lambda=0.001
# - Fold06.Rep2: alpha=0, lambda=0.001
# + Fold07.Rep2: alpha=0, lambda=0.001
# - Fold07.Rep2: alpha=0, lambda=0.001
# + Fold08.Rep2: alpha=0, lambda=0.001
# - Fold08.Rep2: alpha=0, lambda=0.001
# + Fold09.Rep2: alpha=0, lambda=0.001
# - Fold09.Rep2: alpha=0, lambda=0.001
# + Fold10.Rep2: alpha=0, lambda=0.001
# - Fold10.Rep2: alpha=0, lambda=0.001
# + Fold01.Rep3: alpha=0, lambda=0.001
# - Fold01.Rep3: alpha=0, lambda=0.001
# + Fold02.Rep3: alpha=0, lambda=0.001
# - Fold02.Rep3: alpha=0, lambda=0.001
# + Fold03.Rep3: alpha=0, lambda=0.001
# - Fold03.Rep3: alpha=0, lambda=0.001
# + Fold04.Rep3: alpha=0, lambda=0.001
# - Fold04.Rep3: alpha=0, lambda=0.001
# + Fold05.Rep3: alpha=0, lambda=0.001
# - Fold05.Rep3: alpha=0, lambda=0.001
# + Fold06.Rep3: alpha=0, lambda=0.001
# - Fold06.Rep3: alpha=0, lambda=0.001
# + Fold07.Rep3: alpha=0, lambda=0.001
# - Fold07.Rep3: alpha=0, lambda=0.001
# + Fold08.Rep3: alpha=0, lambda=0.001
# - Fold08.Rep3: alpha=0, lambda=0.001
# + Fold09.Rep3: alpha=0, lambda=0.001
# - Fold09.Rep3: alpha=0, lambda=0.001
# + Fold10.Rep3: alpha=0, lambda=0.001
# - Fold10.Rep3: alpha=0, lambda=0.001
# + Fold01.Rep4: alpha=0, lambda=0.001
# - Fold01.Rep4: alpha=0, lambda=0.001
# + Fold02.Rep4: alpha=0, lambda=0.001
# - Fold02.Rep4: alpha=0, lambda=0.001
# + Fold03.Rep4: alpha=0, lambda=0.001
# - Fold03.Rep4: alpha=0, lambda=0.001
# + Fold04.Rep4: alpha=0, lambda=0.001
# - Fold04.Rep4: alpha=0, lambda=0.001
# + Fold05.Rep4: alpha=0, lambda=0.001
# - Fold05.Rep4: alpha=0, lambda=0.001
# + Fold06.Rep4: alpha=0, lambda=0.001
# - Fold06.Rep4: alpha=0, lambda=0.001
# + Fold07.Rep4: alpha=0, lambda=0.001
# - Fold07.Rep4: alpha=0, lambda=0.001
# + Fold08.Rep4: alpha=0, lambda=0.001
# - Fold08.Rep4: alpha=0, lambda=0.001
# + Fold09.Rep4: alpha=0, lambda=0.001
# - Fold09.Rep4: alpha=0, lambda=0.001
# + Fold10.Rep4: alpha=0, lambda=0.001
# - Fold10.Rep4: alpha=0, lambda=0.001
# + Fold01.Rep5: alpha=0, lambda=0.001
# - Fold01.Rep5: alpha=0, lambda=0.001
# + Fold02.Rep5: alpha=0, lambda=0.001
# - Fold02.Rep5: alpha=0, lambda=0.001
# + Fold03.Rep5: alpha=0, lambda=0.001
# - Fold03.Rep5: alpha=0, lambda=0.001
# + Fold04.Rep5: alpha=0, lambda=0.001
# - Fold04.Rep5: alpha=0, lambda=0.001
# + Fold05.Rep5: alpha=0, lambda=0.001
# - Fold05.Rep5: alpha=0, lambda=0.001
# + Fold06.Rep5: alpha=0, lambda=0.001
# - Fold06.Rep5: alpha=0, lambda=0.001
# + Fold07.Rep5: alpha=0, lambda=0.001
# - Fold07.Rep5: alpha=0, lambda=0.001
# + Fold08.Rep5: alpha=0, lambda=0.001
# - Fold08.Rep5: alpha=0, lambda=0.001
# + Fold09.Rep5: alpha=0, lambda=0.001
# - Fold09.Rep5: alpha=0, lambda=0.001
# + Fold10.Rep5: alpha=0, lambda=0.001
# - Fold10.Rep5: alpha=0, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.1, lambda=0.001
# - Fold01.Rep1: alpha=0.1, lambda=0.001
# + Fold02.Rep1: alpha=0.1, lambda=0.001
# - Fold02.Rep1: alpha=0.1, lambda=0.001
# + Fold03.Rep1: alpha=0.1, lambda=0.001
# - Fold03.Rep1: alpha=0.1, lambda=0.001
# + Fold04.Rep1: alpha=0.1, lambda=0.001
# - Fold04.Rep1: alpha=0.1, lambda=0.001
# + Fold05.Rep1: alpha=0.1, lambda=0.001
# - Fold05.Rep1: alpha=0.1, lambda=0.001
# + Fold06.Rep1: alpha=0.1, lambda=0.001
# - Fold06.Rep1: alpha=0.1, lambda=0.001
# + Fold07.Rep1: alpha=0.1, lambda=0.001
# - Fold07.Rep1: alpha=0.1, lambda=0.001
# + Fold08.Rep1: alpha=0.1, lambda=0.001
# - Fold08.Rep1: alpha=0.1, lambda=0.001
# + Fold09.Rep1: alpha=0.1, lambda=0.001
# - Fold09.Rep1: alpha=0.1, lambda=0.001
# + Fold10.Rep1: alpha=0.1, lambda=0.001
# - Fold10.Rep1: alpha=0.1, lambda=0.001
# + Fold01.Rep2: alpha=0.1, lambda=0.001
# - Fold01.Rep2: alpha=0.1, lambda=0.001
# + Fold02.Rep2: alpha=0.1, lambda=0.001
# - Fold02.Rep2: alpha=0.1, lambda=0.001
# + Fold03.Rep2: alpha=0.1, lambda=0.001
# - Fold03.Rep2: alpha=0.1, lambda=0.001
# + Fold04.Rep2: alpha=0.1, lambda=0.001
# - Fold04.Rep2: alpha=0.1, lambda=0.001
# + Fold05.Rep2: alpha=0.1, lambda=0.001
# - Fold05.Rep2: alpha=0.1, lambda=0.001
# + Fold06.Rep2: alpha=0.1, lambda=0.001
# - Fold06.Rep2: alpha=0.1, lambda=0.001
# + Fold07.Rep2: alpha=0.1, lambda=0.001
# - Fold07.Rep2: alpha=0.1, lambda=0.001
# + Fold08.Rep2: alpha=0.1, lambda=0.001
# - Fold08.Rep2: alpha=0.1, lambda=0.001
# + Fold09.Rep2: alpha=0.1, lambda=0.001
# - Fold09.Rep2: alpha=0.1, lambda=0.001
# + Fold10.Rep2: alpha=0.1, lambda=0.001
# - Fold10.Rep2: alpha=0.1, lambda=0.001
# + Fold01.Rep3: alpha=0.1, lambda=0.001
# - Fold01.Rep3: alpha=0.1, lambda=0.001
# + Fold02.Rep3: alpha=0.1, lambda=0.001
# - Fold02.Rep3: alpha=0.1, lambda=0.001
# + Fold03.Rep3: alpha=0.1, lambda=0.001
# - Fold03.Rep3: alpha=0.1, lambda=0.001
# + Fold04.Rep3: alpha=0.1, lambda=0.001
# - Fold04.Rep3: alpha=0.1, lambda=0.001
# + Fold05.Rep3: alpha=0.1, lambda=0.001
# - Fold05.Rep3: alpha=0.1, lambda=0.001
# + Fold06.Rep3: alpha=0.1, lambda=0.001
# - Fold06.Rep3: alpha=0.1, lambda=0.001
# + Fold07.Rep3: alpha=0.1, lambda=0.001
# - Fold07.Rep3: alpha=0.1, lambda=0.001
# + Fold08.Rep3: alpha=0.1, lambda=0.001
# - Fold08.Rep3: alpha=0.1, lambda=0.001
# + Fold09.Rep3: alpha=0.1, lambda=0.001
# - Fold09.Rep3: alpha=0.1, lambda=0.001
# + Fold10.Rep3: alpha=0.1, lambda=0.001
# - Fold10.Rep3: alpha=0.1, lambda=0.001
# + Fold01.Rep4: alpha=0.1, lambda=0.001
# - Fold01.Rep4: alpha=0.1, lambda=0.001
# + Fold02.Rep4: alpha=0.1, lambda=0.001
# - Fold02.Rep4: alpha=0.1, lambda=0.001
# + Fold03.Rep4: alpha=0.1, lambda=0.001
# - Fold03.Rep4: alpha=0.1, lambda=0.001
# + Fold04.Rep4: alpha=0.1, lambda=0.001
# - Fold04.Rep4: alpha=0.1, lambda=0.001
# + Fold05.Rep4: alpha=0.1, lambda=0.001
# - Fold05.Rep4: alpha=0.1, lambda=0.001
# + Fold06.Rep4: alpha=0.1, lambda=0.001
# - Fold06.Rep4: alpha=0.1, lambda=0.001
# + Fold07.Rep4: alpha=0.1, lambda=0.001
# - Fold07.Rep4: alpha=0.1, lambda=0.001
# + Fold08.Rep4: alpha=0.1, lambda=0.001
# - Fold08.Rep4: alpha=0.1, lambda=0.001
# + Fold09.Rep4: alpha=0.1, lambda=0.001
# - Fold09.Rep4: alpha=0.1, lambda=0.001
# + Fold10.Rep4: alpha=0.1, lambda=0.001
# - Fold10.Rep4: alpha=0.1, lambda=0.001
# + Fold01.Rep5: alpha=0.1, lambda=0.001
# - Fold01.Rep5: alpha=0.1, lambda=0.001
# + Fold02.Rep5: alpha=0.1, lambda=0.001
# - Fold02.Rep5: alpha=0.1, lambda=0.001
# + Fold03.Rep5: alpha=0.1, lambda=0.001
# - Fold03.Rep5: alpha=0.1, lambda=0.001
# + Fold04.Rep5: alpha=0.1, lambda=0.001
# - Fold04.Rep5: alpha=0.1, lambda=0.001
# + Fold05.Rep5: alpha=0.1, lambda=0.001
# - Fold05.Rep5: alpha=0.1, lambda=0.001
# + Fold06.Rep5: alpha=0.1, lambda=0.001
# - Fold06.Rep5: alpha=0.1, lambda=0.001
# + Fold07.Rep5: alpha=0.1, lambda=0.001
# - Fold07.Rep5: alpha=0.1, lambda=0.001
# + Fold08.Rep5: alpha=0.1, lambda=0.001
# - Fold08.Rep5: alpha=0.1, lambda=0.001
# + Fold09.Rep5: alpha=0.1, lambda=0.001
# - Fold09.Rep5: alpha=0.1, lambda=0.001
# + Fold10.Rep5: alpha=0.1, lambda=0.001
# - Fold10.Rep5: alpha=0.1, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.2, lambda=0.001
# - Fold01.Rep1: alpha=0.2, lambda=0.001
# + Fold02.Rep1: alpha=0.2, lambda=0.001
# - Fold02.Rep1: alpha=0.2, lambda=0.001
# + Fold03.Rep1: alpha=0.2, lambda=0.001
# - Fold03.Rep1: alpha=0.2, lambda=0.001
# + Fold04.Rep1: alpha=0.2, lambda=0.001
# - Fold04.Rep1: alpha=0.2, lambda=0.001
# + Fold05.Rep1: alpha=0.2, lambda=0.001
# - Fold05.Rep1: alpha=0.2, lambda=0.001
# + Fold06.Rep1: alpha=0.2, lambda=0.001
# - Fold06.Rep1: alpha=0.2, lambda=0.001
# + Fold07.Rep1: alpha=0.2, lambda=0.001
# - Fold07.Rep1: alpha=0.2, lambda=0.001
# + Fold08.Rep1: alpha=0.2, lambda=0.001
# - Fold08.Rep1: alpha=0.2, lambda=0.001
# + Fold09.Rep1: alpha=0.2, lambda=0.001
# - Fold09.Rep1: alpha=0.2, lambda=0.001
# + Fold10.Rep1: alpha=0.2, lambda=0.001
# - Fold10.Rep1: alpha=0.2, lambda=0.001
# + Fold01.Rep2: alpha=0.2, lambda=0.001
# - Fold01.Rep2: alpha=0.2, lambda=0.001
# + Fold02.Rep2: alpha=0.2, lambda=0.001
# - Fold02.Rep2: alpha=0.2, lambda=0.001
# + Fold03.Rep2: alpha=0.2, lambda=0.001
# - Fold03.Rep2: alpha=0.2, lambda=0.001
# + Fold04.Rep2: alpha=0.2, lambda=0.001
# - Fold04.Rep2: alpha=0.2, lambda=0.001
# + Fold05.Rep2: alpha=0.2, lambda=0.001
# - Fold05.Rep2: alpha=0.2, lambda=0.001
# + Fold06.Rep2: alpha=0.2, lambda=0.001
# - Fold06.Rep2: alpha=0.2, lambda=0.001
# + Fold07.Rep2: alpha=0.2, lambda=0.001
# - Fold07.Rep2: alpha=0.2, lambda=0.001
# + Fold08.Rep2: alpha=0.2, lambda=0.001
# - Fold08.Rep2: alpha=0.2, lambda=0.001
# + Fold09.Rep2: alpha=0.2, lambda=0.001
# - Fold09.Rep2: alpha=0.2, lambda=0.001
# + Fold10.Rep2: alpha=0.2, lambda=0.001
# - Fold10.Rep2: alpha=0.2, lambda=0.001
# + Fold01.Rep3: alpha=0.2, lambda=0.001
# - Fold01.Rep3: alpha=0.2, lambda=0.001
# + Fold02.Rep3: alpha=0.2, lambda=0.001
# - Fold02.Rep3: alpha=0.2, lambda=0.001
# + Fold03.Rep3: alpha=0.2, lambda=0.001
# - Fold03.Rep3: alpha=0.2, lambda=0.001
# + Fold04.Rep3: alpha=0.2, lambda=0.001
# - Fold04.Rep3: alpha=0.2, lambda=0.001
# + Fold05.Rep3: alpha=0.2, lambda=0.001
# - Fold05.Rep3: alpha=0.2, lambda=0.001
# + Fold06.Rep3: alpha=0.2, lambda=0.001
# - Fold06.Rep3: alpha=0.2, lambda=0.001
# + Fold07.Rep3: alpha=0.2, lambda=0.001
# - Fold07.Rep3: alpha=0.2, lambda=0.001
# + Fold08.Rep3: alpha=0.2, lambda=0.001
# - Fold08.Rep3: alpha=0.2, lambda=0.001
# + Fold09.Rep3: alpha=0.2, lambda=0.001
# - Fold09.Rep3: alpha=0.2, lambda=0.001
# + Fold10.Rep3: alpha=0.2, lambda=0.001
# - Fold10.Rep3: alpha=0.2, lambda=0.001
# + Fold01.Rep4: alpha=0.2, lambda=0.001
# - Fold01.Rep4: alpha=0.2, lambda=0.001
# + Fold02.Rep4: alpha=0.2, lambda=0.001
# - Fold02.Rep4: alpha=0.2, lambda=0.001
# + Fold03.Rep4: alpha=0.2, lambda=0.001
# - Fold03.Rep4: alpha=0.2, lambda=0.001
# + Fold04.Rep4: alpha=0.2, lambda=0.001
# - Fold04.Rep4: alpha=0.2, lambda=0.001
# + Fold05.Rep4: alpha=0.2, lambda=0.001
# - Fold05.Rep4: alpha=0.2, lambda=0.001
# + Fold06.Rep4: alpha=0.2, lambda=0.001
# - Fold06.Rep4: alpha=0.2, lambda=0.001
# + Fold07.Rep4: alpha=0.2, lambda=0.001
# - Fold07.Rep4: alpha=0.2, lambda=0.001
# + Fold08.Rep4: alpha=0.2, lambda=0.001
# - Fold08.Rep4: alpha=0.2, lambda=0.001
# + Fold09.Rep4: alpha=0.2, lambda=0.001
# - Fold09.Rep4: alpha=0.2, lambda=0.001
# + Fold10.Rep4: alpha=0.2, lambda=0.001
# - Fold10.Rep4: alpha=0.2, lambda=0.001
# + Fold01.Rep5: alpha=0.2, lambda=0.001
# - Fold01.Rep5: alpha=0.2, lambda=0.001
# + Fold02.Rep5: alpha=0.2, lambda=0.001
# - Fold02.Rep5: alpha=0.2, lambda=0.001
# + Fold03.Rep5: alpha=0.2, lambda=0.001
# - Fold03.Rep5: alpha=0.2, lambda=0.001
# + Fold04.Rep5: alpha=0.2, lambda=0.001
# - Fold04.Rep5: alpha=0.2, lambda=0.001
# + Fold05.Rep5: alpha=0.2, lambda=0.001
# - Fold05.Rep5: alpha=0.2, lambda=0.001
# + Fold06.Rep5: alpha=0.2, lambda=0.001
# - Fold06.Rep5: alpha=0.2, lambda=0.001
# + Fold07.Rep5: alpha=0.2, lambda=0.001
# - Fold07.Rep5: alpha=0.2, lambda=0.001
# + Fold08.Rep5: alpha=0.2, lambda=0.001
# - Fold08.Rep5: alpha=0.2, lambda=0.001
# + Fold09.Rep5: alpha=0.2, lambda=0.001
# - Fold09.Rep5: alpha=0.2, lambda=0.001
# + Fold10.Rep5: alpha=0.2, lambda=0.001
# - Fold10.Rep5: alpha=0.2, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.3, lambda=0.001
# - Fold01.Rep1: alpha=0.3, lambda=0.001
# + Fold02.Rep1: alpha=0.3, lambda=0.001
# - Fold02.Rep1: alpha=0.3, lambda=0.001
# + Fold03.Rep1: alpha=0.3, lambda=0.001
# - Fold03.Rep1: alpha=0.3, lambda=0.001
# + Fold04.Rep1: alpha=0.3, lambda=0.001
# - Fold04.Rep1: alpha=0.3, lambda=0.001
# + Fold05.Rep1: alpha=0.3, lambda=0.001
# - Fold05.Rep1: alpha=0.3, lambda=0.001
# + Fold06.Rep1: alpha=0.3, lambda=0.001
# - Fold06.Rep1: alpha=0.3, lambda=0.001
# + Fold07.Rep1: alpha=0.3, lambda=0.001
# - Fold07.Rep1: alpha=0.3, lambda=0.001
# + Fold08.Rep1: alpha=0.3, lambda=0.001
# - Fold08.Rep1: alpha=0.3, lambda=0.001
# + Fold09.Rep1: alpha=0.3, lambda=0.001
# - Fold09.Rep1: alpha=0.3, lambda=0.001
# + Fold10.Rep1: alpha=0.3, lambda=0.001
# - Fold10.Rep1: alpha=0.3, lambda=0.001
# + Fold01.Rep2: alpha=0.3, lambda=0.001
# - Fold01.Rep2: alpha=0.3, lambda=0.001
# + Fold02.Rep2: alpha=0.3, lambda=0.001
# - Fold02.Rep2: alpha=0.3, lambda=0.001
# + Fold03.Rep2: alpha=0.3, lambda=0.001
# - Fold03.Rep2: alpha=0.3, lambda=0.001
# + Fold04.Rep2: alpha=0.3, lambda=0.001
# - Fold04.Rep2: alpha=0.3, lambda=0.001
# + Fold05.Rep2: alpha=0.3, lambda=0.001
# - Fold05.Rep2: alpha=0.3, lambda=0.001
# + Fold06.Rep2: alpha=0.3, lambda=0.001
# - Fold06.Rep2: alpha=0.3, lambda=0.001
# + Fold07.Rep2: alpha=0.3, lambda=0.001
# - Fold07.Rep2: alpha=0.3, lambda=0.001
# + Fold08.Rep2: alpha=0.3, lambda=0.001
# - Fold08.Rep2: alpha=0.3, lambda=0.001
# + Fold09.Rep2: alpha=0.3, lambda=0.001
# - Fold09.Rep2: alpha=0.3, lambda=0.001
# + Fold10.Rep2: alpha=0.3, lambda=0.001
# - Fold10.Rep2: alpha=0.3, lambda=0.001
# + Fold01.Rep3: alpha=0.3, lambda=0.001
# - Fold01.Rep3: alpha=0.3, lambda=0.001
# + Fold02.Rep3: alpha=0.3, lambda=0.001
# - Fold02.Rep3: alpha=0.3, lambda=0.001
# + Fold03.Rep3: alpha=0.3, lambda=0.001
# - Fold03.Rep3: alpha=0.3, lambda=0.001
# + Fold04.Rep3: alpha=0.3, lambda=0.001
# - Fold04.Rep3: alpha=0.3, lambda=0.001
# + Fold05.Rep3: alpha=0.3, lambda=0.001
# - Fold05.Rep3: alpha=0.3, lambda=0.001
# + Fold06.Rep3: alpha=0.3, lambda=0.001
# - Fold06.Rep3: alpha=0.3, lambda=0.001
# + Fold07.Rep3: alpha=0.3, lambda=0.001
# - Fold07.Rep3: alpha=0.3, lambda=0.001
# + Fold08.Rep3: alpha=0.3, lambda=0.001
# - Fold08.Rep3: alpha=0.3, lambda=0.001
# + Fold09.Rep3: alpha=0.3, lambda=0.001
# - Fold09.Rep3: alpha=0.3, lambda=0.001
# + Fold10.Rep3: alpha=0.3, lambda=0.001
# - Fold10.Rep3: alpha=0.3, lambda=0.001
# + Fold01.Rep4: alpha=0.3, lambda=0.001
# - Fold01.Rep4: alpha=0.3, lambda=0.001
# + Fold02.Rep4: alpha=0.3, lambda=0.001
# - Fold02.Rep4: alpha=0.3, lambda=0.001
# + Fold03.Rep4: alpha=0.3, lambda=0.001
# - Fold03.Rep4: alpha=0.3, lambda=0.001
# + Fold04.Rep4: alpha=0.3, lambda=0.001
# - Fold04.Rep4: alpha=0.3, lambda=0.001
# + Fold05.Rep4: alpha=0.3, lambda=0.001
# - Fold05.Rep4: alpha=0.3, lambda=0.001
# + Fold06.Rep4: alpha=0.3, lambda=0.001
# - Fold06.Rep4: alpha=0.3, lambda=0.001
# + Fold07.Rep4: alpha=0.3, lambda=0.001
# - Fold07.Rep4: alpha=0.3, lambda=0.001
# + Fold08.Rep4: alpha=0.3, lambda=0.001
# - Fold08.Rep4: alpha=0.3, lambda=0.001
# + Fold09.Rep4: alpha=0.3, lambda=0.001
# - Fold09.Rep4: alpha=0.3, lambda=0.001
# + Fold10.Rep4: alpha=0.3, lambda=0.001
# - Fold10.Rep4: alpha=0.3, lambda=0.001
# + Fold01.Rep5: alpha=0.3, lambda=0.001
# - Fold01.Rep5: alpha=0.3, lambda=0.001
# + Fold02.Rep5: alpha=0.3, lambda=0.001
# - Fold02.Rep5: alpha=0.3, lambda=0.001
# + Fold03.Rep5: alpha=0.3, lambda=0.001
# - Fold03.Rep5: alpha=0.3, lambda=0.001
# + Fold04.Rep5: alpha=0.3, lambda=0.001
# - Fold04.Rep5: alpha=0.3, lambda=0.001
# + Fold05.Rep5: alpha=0.3, lambda=0.001
# - Fold05.Rep5: alpha=0.3, lambda=0.001
# + Fold06.Rep5: alpha=0.3, lambda=0.001
# - Fold06.Rep5: alpha=0.3, lambda=0.001
# + Fold07.Rep5: alpha=0.3, lambda=0.001
# - Fold07.Rep5: alpha=0.3, lambda=0.001
# + Fold08.Rep5: alpha=0.3, lambda=0.001
# - Fold08.Rep5: alpha=0.3, lambda=0.001
# + Fold09.Rep5: alpha=0.3, lambda=0.001
# - Fold09.Rep5: alpha=0.3, lambda=0.001
# + Fold10.Rep5: alpha=0.3, lambda=0.001
# - Fold10.Rep5: alpha=0.3, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.4, lambda=0.001
# - Fold01.Rep1: alpha=0.4, lambda=0.001
# + Fold02.Rep1: alpha=0.4, lambda=0.001
# - Fold02.Rep1: alpha=0.4, lambda=0.001
# + Fold03.Rep1: alpha=0.4, lambda=0.001
# - Fold03.Rep1: alpha=0.4, lambda=0.001
# + Fold04.Rep1: alpha=0.4, lambda=0.001
# - Fold04.Rep1: alpha=0.4, lambda=0.001
# + Fold05.Rep1: alpha=0.4, lambda=0.001
# - Fold05.Rep1: alpha=0.4, lambda=0.001
# + Fold06.Rep1: alpha=0.4, lambda=0.001
# - Fold06.Rep1: alpha=0.4, lambda=0.001
# + Fold07.Rep1: alpha=0.4, lambda=0.001
# - Fold07.Rep1: alpha=0.4, lambda=0.001
# + Fold08.Rep1: alpha=0.4, lambda=0.001
# - Fold08.Rep1: alpha=0.4, lambda=0.001
# + Fold09.Rep1: alpha=0.4, lambda=0.001
# - Fold09.Rep1: alpha=0.4, lambda=0.001
# + Fold10.Rep1: alpha=0.4, lambda=0.001
# - Fold10.Rep1: alpha=0.4, lambda=0.001
# + Fold01.Rep2: alpha=0.4, lambda=0.001
# - Fold01.Rep2: alpha=0.4, lambda=0.001
# + Fold02.Rep2: alpha=0.4, lambda=0.001
# - Fold02.Rep2: alpha=0.4, lambda=0.001
# + Fold03.Rep2: alpha=0.4, lambda=0.001
# - Fold03.Rep2: alpha=0.4, lambda=0.001
# + Fold04.Rep2: alpha=0.4, lambda=0.001
# - Fold04.Rep2: alpha=0.4, lambda=0.001
# + Fold05.Rep2: alpha=0.4, lambda=0.001
# - Fold05.Rep2: alpha=0.4, lambda=0.001
# + Fold06.Rep2: alpha=0.4, lambda=0.001
# - Fold06.Rep2: alpha=0.4, lambda=0.001
# + Fold07.Rep2: alpha=0.4, lambda=0.001
# - Fold07.Rep2: alpha=0.4, lambda=0.001
# + Fold08.Rep2: alpha=0.4, lambda=0.001
# - Fold08.Rep2: alpha=0.4, lambda=0.001
# + Fold09.Rep2: alpha=0.4, lambda=0.001
# - Fold09.Rep2: alpha=0.4, lambda=0.001
# + Fold10.Rep2: alpha=0.4, lambda=0.001
# - Fold10.Rep2: alpha=0.4, lambda=0.001
# + Fold01.Rep3: alpha=0.4, lambda=0.001
# - Fold01.Rep3: alpha=0.4, lambda=0.001
# + Fold02.Rep3: alpha=0.4, lambda=0.001
# - Fold02.Rep3: alpha=0.4, lambda=0.001
# + Fold03.Rep3: alpha=0.4, lambda=0.001
# - Fold03.Rep3: alpha=0.4, lambda=0.001
# + Fold04.Rep3: alpha=0.4, lambda=0.001
# - Fold04.Rep3: alpha=0.4, lambda=0.001
# + Fold05.Rep3: alpha=0.4, lambda=0.001
# - Fold05.Rep3: alpha=0.4, lambda=0.001
# + Fold06.Rep3: alpha=0.4, lambda=0.001
# - Fold06.Rep3: alpha=0.4, lambda=0.001
# + Fold07.Rep3: alpha=0.4, lambda=0.001
# - Fold07.Rep3: alpha=0.4, lambda=0.001
# + Fold08.Rep3: alpha=0.4, lambda=0.001
# - Fold08.Rep3: alpha=0.4, lambda=0.001
# + Fold09.Rep3: alpha=0.4, lambda=0.001
# - Fold09.Rep3: alpha=0.4, lambda=0.001
# + Fold10.Rep3: alpha=0.4, lambda=0.001
# - Fold10.Rep3: alpha=0.4, lambda=0.001
# + Fold01.Rep4: alpha=0.4, lambda=0.001
# - Fold01.Rep4: alpha=0.4, lambda=0.001
# + Fold02.Rep4: alpha=0.4, lambda=0.001
# - Fold02.Rep4: alpha=0.4, lambda=0.001
# + Fold03.Rep4: alpha=0.4, lambda=0.001
# - Fold03.Rep4: alpha=0.4, lambda=0.001
# + Fold04.Rep4: alpha=0.4, lambda=0.001
# - Fold04.Rep4: alpha=0.4, lambda=0.001
# + Fold05.Rep4: alpha=0.4, lambda=0.001
# - Fold05.Rep4: alpha=0.4, lambda=0.001
# + Fold06.Rep4: alpha=0.4, lambda=0.001
# - Fold06.Rep4: alpha=0.4, lambda=0.001
# + Fold07.Rep4: alpha=0.4, lambda=0.001
# - Fold07.Rep4: alpha=0.4, lambda=0.001
# + Fold08.Rep4: alpha=0.4, lambda=0.001
# - Fold08.Rep4: alpha=0.4, lambda=0.001
# + Fold09.Rep4: alpha=0.4, lambda=0.001
# - Fold09.Rep4: alpha=0.4, lambda=0.001
# + Fold10.Rep4: alpha=0.4, lambda=0.001
# - Fold10.Rep4: alpha=0.4, lambda=0.001
# + Fold01.Rep5: alpha=0.4, lambda=0.001
# - Fold01.Rep5: alpha=0.4, lambda=0.001
# + Fold02.Rep5: alpha=0.4, lambda=0.001
# - Fold02.Rep5: alpha=0.4, lambda=0.001
# + Fold03.Rep5: alpha=0.4, lambda=0.001
# - Fold03.Rep5: alpha=0.4, lambda=0.001
# + Fold04.Rep5: alpha=0.4, lambda=0.001
# - Fold04.Rep5: alpha=0.4, lambda=0.001
# + Fold05.Rep5: alpha=0.4, lambda=0.001
# - Fold05.Rep5: alpha=0.4, lambda=0.001
# + Fold06.Rep5: alpha=0.4, lambda=0.001
# - Fold06.Rep5: alpha=0.4, lambda=0.001
# + Fold07.Rep5: alpha=0.4, lambda=0.001
# - Fold07.Rep5: alpha=0.4, lambda=0.001
# + Fold08.Rep5: alpha=0.4, lambda=0.001
# - Fold08.Rep5: alpha=0.4, lambda=0.001
# + Fold09.Rep5: alpha=0.4, lambda=0.001
# - Fold09.Rep5: alpha=0.4, lambda=0.001
# + Fold10.Rep5: alpha=0.4, lambda=0.001
# - Fold10.Rep5: alpha=0.4, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.5, lambda=0.001
# - Fold01.Rep1: alpha=0.5, lambda=0.001
# + Fold02.Rep1: alpha=0.5, lambda=0.001
# - Fold02.Rep1: alpha=0.5, lambda=0.001
# + Fold03.Rep1: alpha=0.5, lambda=0.001
# - Fold03.Rep1: alpha=0.5, lambda=0.001
# + Fold04.Rep1: alpha=0.5, lambda=0.001
# - Fold04.Rep1: alpha=0.5, lambda=0.001
# + Fold05.Rep1: alpha=0.5, lambda=0.001
# - Fold05.Rep1: alpha=0.5, lambda=0.001
# + Fold06.Rep1: alpha=0.5, lambda=0.001
# - Fold06.Rep1: alpha=0.5, lambda=0.001
# + Fold07.Rep1: alpha=0.5, lambda=0.001
# - Fold07.Rep1: alpha=0.5, lambda=0.001
# + Fold08.Rep1: alpha=0.5, lambda=0.001
# - Fold08.Rep1: alpha=0.5, lambda=0.001
# + Fold09.Rep1: alpha=0.5, lambda=0.001
# - Fold09.Rep1: alpha=0.5, lambda=0.001
# + Fold10.Rep1: alpha=0.5, lambda=0.001
# - Fold10.Rep1: alpha=0.5, lambda=0.001
# + Fold01.Rep2: alpha=0.5, lambda=0.001
# - Fold01.Rep2: alpha=0.5, lambda=0.001
# + Fold02.Rep2: alpha=0.5, lambda=0.001
# - Fold02.Rep2: alpha=0.5, lambda=0.001
# + Fold03.Rep2: alpha=0.5, lambda=0.001
# - Fold03.Rep2: alpha=0.5, lambda=0.001
# + Fold04.Rep2: alpha=0.5, lambda=0.001
# - Fold04.Rep2: alpha=0.5, lambda=0.001
# + Fold05.Rep2: alpha=0.5, lambda=0.001
# - Fold05.Rep2: alpha=0.5, lambda=0.001
# + Fold06.Rep2: alpha=0.5, lambda=0.001
# - Fold06.Rep2: alpha=0.5, lambda=0.001
# + Fold07.Rep2: alpha=0.5, lambda=0.001
# - Fold07.Rep2: alpha=0.5, lambda=0.001
# + Fold08.Rep2: alpha=0.5, lambda=0.001
# - Fold08.Rep2: alpha=0.5, lambda=0.001
# + Fold09.Rep2: alpha=0.5, lambda=0.001
# - Fold09.Rep2: alpha=0.5, lambda=0.001
# + Fold10.Rep2: alpha=0.5, lambda=0.001
# - Fold10.Rep2: alpha=0.5, lambda=0.001
# + Fold01.Rep3: alpha=0.5, lambda=0.001
# - Fold01.Rep3: alpha=0.5, lambda=0.001
# + Fold02.Rep3: alpha=0.5, lambda=0.001
# - Fold02.Rep3: alpha=0.5, lambda=0.001
# + Fold03.Rep3: alpha=0.5, lambda=0.001
# - Fold03.Rep3: alpha=0.5, lambda=0.001
# + Fold04.Rep3: alpha=0.5, lambda=0.001
# - Fold04.Rep3: alpha=0.5, lambda=0.001
# + Fold05.Rep3: alpha=0.5, lambda=0.001
# - Fold05.Rep3: alpha=0.5, lambda=0.001
# + Fold06.Rep3: alpha=0.5, lambda=0.001
# - Fold06.Rep3: alpha=0.5, lambda=0.001
# + Fold07.Rep3: alpha=0.5, lambda=0.001
# - Fold07.Rep3: alpha=0.5, lambda=0.001
# + Fold08.Rep3: alpha=0.5, lambda=0.001
# - Fold08.Rep3: alpha=0.5, lambda=0.001
# + Fold09.Rep3: alpha=0.5, lambda=0.001
# - Fold09.Rep3: alpha=0.5, lambda=0.001
# + Fold10.Rep3: alpha=0.5, lambda=0.001
# - Fold10.Rep3: alpha=0.5, lambda=0.001
# + Fold01.Rep4: alpha=0.5, lambda=0.001
# - Fold01.Rep4: alpha=0.5, lambda=0.001
# + Fold02.Rep4: alpha=0.5, lambda=0.001
# - Fold02.Rep4: alpha=0.5, lambda=0.001
# + Fold03.Rep4: alpha=0.5, lambda=0.001
# - Fold03.Rep4: alpha=0.5, lambda=0.001
# + Fold04.Rep4: alpha=0.5, lambda=0.001
# - Fold04.Rep4: alpha=0.5, lambda=0.001
# + Fold05.Rep4: alpha=0.5, lambda=0.001
# - Fold05.Rep4: alpha=0.5, lambda=0.001
# + Fold06.Rep4: alpha=0.5, lambda=0.001
# - Fold06.Rep4: alpha=0.5, lambda=0.001
# + Fold07.Rep4: alpha=0.5, lambda=0.001
# - Fold07.Rep4: alpha=0.5, lambda=0.001
# + Fold08.Rep4: alpha=0.5, lambda=0.001
# - Fold08.Rep4: alpha=0.5, lambda=0.001
# + Fold09.Rep4: alpha=0.5, lambda=0.001
# - Fold09.Rep4: alpha=0.5, lambda=0.001
# + Fold10.Rep4: alpha=0.5, lambda=0.001
# - Fold10.Rep4: alpha=0.5, lambda=0.001
# + Fold01.Rep5: alpha=0.5, lambda=0.001
# - Fold01.Rep5: alpha=0.5, lambda=0.001
# + Fold02.Rep5: alpha=0.5, lambda=0.001
# - Fold02.Rep5: alpha=0.5, lambda=0.001
# + Fold03.Rep5: alpha=0.5, lambda=0.001
# - Fold03.Rep5: alpha=0.5, lambda=0.001
# + Fold04.Rep5: alpha=0.5, lambda=0.001
# - Fold04.Rep5: alpha=0.5, lambda=0.001
# + Fold05.Rep5: alpha=0.5, lambda=0.001
# - Fold05.Rep5: alpha=0.5, lambda=0.001
# + Fold06.Rep5: alpha=0.5, lambda=0.001
# - Fold06.Rep5: alpha=0.5, lambda=0.001
# + Fold07.Rep5: alpha=0.5, lambda=0.001
# - Fold07.Rep5: alpha=0.5, lambda=0.001
# + Fold08.Rep5: alpha=0.5, lambda=0.001
# - Fold08.Rep5: alpha=0.5, lambda=0.001
# + Fold09.Rep5: alpha=0.5, lambda=0.001
# - Fold09.Rep5: alpha=0.5, lambda=0.001
# + Fold10.Rep5: alpha=0.5, lambda=0.001
# - Fold10.Rep5: alpha=0.5, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.6, lambda=0.001
# - Fold01.Rep1: alpha=0.6, lambda=0.001
# + Fold02.Rep1: alpha=0.6, lambda=0.001
# - Fold02.Rep1: alpha=0.6, lambda=0.001
# + Fold03.Rep1: alpha=0.6, lambda=0.001
# - Fold03.Rep1: alpha=0.6, lambda=0.001
# + Fold04.Rep1: alpha=0.6, lambda=0.001
# - Fold04.Rep1: alpha=0.6, lambda=0.001
# + Fold05.Rep1: alpha=0.6, lambda=0.001
# - Fold05.Rep1: alpha=0.6, lambda=0.001
# + Fold06.Rep1: alpha=0.6, lambda=0.001
# - Fold06.Rep1: alpha=0.6, lambda=0.001
# + Fold07.Rep1: alpha=0.6, lambda=0.001
# - Fold07.Rep1: alpha=0.6, lambda=0.001
# + Fold08.Rep1: alpha=0.6, lambda=0.001
# - Fold08.Rep1: alpha=0.6, lambda=0.001
# + Fold09.Rep1: alpha=0.6, lambda=0.001
# - Fold09.Rep1: alpha=0.6, lambda=0.001
# + Fold10.Rep1: alpha=0.6, lambda=0.001
# - Fold10.Rep1: alpha=0.6, lambda=0.001
# + Fold01.Rep2: alpha=0.6, lambda=0.001
# - Fold01.Rep2: alpha=0.6, lambda=0.001
# + Fold02.Rep2: alpha=0.6, lambda=0.001
# - Fold02.Rep2: alpha=0.6, lambda=0.001
# + Fold03.Rep2: alpha=0.6, lambda=0.001
# - Fold03.Rep2: alpha=0.6, lambda=0.001
# + Fold04.Rep2: alpha=0.6, lambda=0.001
# - Fold04.Rep2: alpha=0.6, lambda=0.001
# + Fold05.Rep2: alpha=0.6, lambda=0.001
# - Fold05.Rep2: alpha=0.6, lambda=0.001
# + Fold06.Rep2: alpha=0.6, lambda=0.001
# - Fold06.Rep2: alpha=0.6, lambda=0.001
# + Fold07.Rep2: alpha=0.6, lambda=0.001
# - Fold07.Rep2: alpha=0.6, lambda=0.001
# + Fold08.Rep2: alpha=0.6, lambda=0.001
# - Fold08.Rep2: alpha=0.6, lambda=0.001
# + Fold09.Rep2: alpha=0.6, lambda=0.001
# - Fold09.Rep2: alpha=0.6, lambda=0.001
# + Fold10.Rep2: alpha=0.6, lambda=0.001
# - Fold10.Rep2: alpha=0.6, lambda=0.001
# + Fold01.Rep3: alpha=0.6, lambda=0.001
# - Fold01.Rep3: alpha=0.6, lambda=0.001
# + Fold02.Rep3: alpha=0.6, lambda=0.001
# - Fold02.Rep3: alpha=0.6, lambda=0.001
# + Fold03.Rep3: alpha=0.6, lambda=0.001
# - Fold03.Rep3: alpha=0.6, lambda=0.001
# + Fold04.Rep3: alpha=0.6, lambda=0.001
# - Fold04.Rep3: alpha=0.6, lambda=0.001
# + Fold05.Rep3: alpha=0.6, lambda=0.001
# - Fold05.Rep3: alpha=0.6, lambda=0.001
# + Fold06.Rep3: alpha=0.6, lambda=0.001
# - Fold06.Rep3: alpha=0.6, lambda=0.001
# + Fold07.Rep3: alpha=0.6, lambda=0.001
# - Fold07.Rep3: alpha=0.6, lambda=0.001
# + Fold08.Rep3: alpha=0.6, lambda=0.001
# - Fold08.Rep3: alpha=0.6, lambda=0.001
# + Fold09.Rep3: alpha=0.6, lambda=0.001
# - Fold09.Rep3: alpha=0.6, lambda=0.001
# + Fold10.Rep3: alpha=0.6, lambda=0.001
# - Fold10.Rep3: alpha=0.6, lambda=0.001
# + Fold01.Rep4: alpha=0.6, lambda=0.001
# - Fold01.Rep4: alpha=0.6, lambda=0.001
# + Fold02.Rep4: alpha=0.6, lambda=0.001
# - Fold02.Rep4: alpha=0.6, lambda=0.001
# + Fold03.Rep4: alpha=0.6, lambda=0.001
# - Fold03.Rep4: alpha=0.6, lambda=0.001
# + Fold04.Rep4: alpha=0.6, lambda=0.001
# - Fold04.Rep4: alpha=0.6, lambda=0.001
# + Fold05.Rep4: alpha=0.6, lambda=0.001
# - Fold05.Rep4: alpha=0.6, lambda=0.001
# + Fold06.Rep4: alpha=0.6, lambda=0.001
# - Fold06.Rep4: alpha=0.6, lambda=0.001
# + Fold07.Rep4: alpha=0.6, lambda=0.001
# - Fold07.Rep4: alpha=0.6, lambda=0.001
# + Fold08.Rep4: alpha=0.6, lambda=0.001
# - Fold08.Rep4: alpha=0.6, lambda=0.001
# + Fold09.Rep4: alpha=0.6, lambda=0.001
# - Fold09.Rep4: alpha=0.6, lambda=0.001
# + Fold10.Rep4: alpha=0.6, lambda=0.001
# - Fold10.Rep4: alpha=0.6, lambda=0.001
# + Fold01.Rep5: alpha=0.6, lambda=0.001
# - Fold01.Rep5: alpha=0.6, lambda=0.001
# + Fold02.Rep5: alpha=0.6, lambda=0.001
# - Fold02.Rep5: alpha=0.6, lambda=0.001
# + Fold03.Rep5: alpha=0.6, lambda=0.001
# - Fold03.Rep5: alpha=0.6, lambda=0.001
# + Fold04.Rep5: alpha=0.6, lambda=0.001
# - Fold04.Rep5: alpha=0.6, lambda=0.001
# + Fold05.Rep5: alpha=0.6, lambda=0.001
# - Fold05.Rep5: alpha=0.6, lambda=0.001
# + Fold06.Rep5: alpha=0.6, lambda=0.001
# - Fold06.Rep5: alpha=0.6, lambda=0.001
# + Fold07.Rep5: alpha=0.6, lambda=0.001
# - Fold07.Rep5: alpha=0.6, lambda=0.001
# + Fold08.Rep5: alpha=0.6, lambda=0.001
# - Fold08.Rep5: alpha=0.6, lambda=0.001
# + Fold09.Rep5: alpha=0.6, lambda=0.001
# - Fold09.Rep5: alpha=0.6, lambda=0.001
# + Fold10.Rep5: alpha=0.6, lambda=0.001
# - Fold10.Rep5: alpha=0.6, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.7, lambda=0.001
# - Fold01.Rep1: alpha=0.7, lambda=0.001
# + Fold02.Rep1: alpha=0.7, lambda=0.001
# - Fold02.Rep1: alpha=0.7, lambda=0.001
# + Fold03.Rep1: alpha=0.7, lambda=0.001
# - Fold03.Rep1: alpha=0.7, lambda=0.001
# + Fold04.Rep1: alpha=0.7, lambda=0.001
# - Fold04.Rep1: alpha=0.7, lambda=0.001
# + Fold05.Rep1: alpha=0.7, lambda=0.001
# - Fold05.Rep1: alpha=0.7, lambda=0.001
# + Fold06.Rep1: alpha=0.7, lambda=0.001
# - Fold06.Rep1: alpha=0.7, lambda=0.001
# + Fold07.Rep1: alpha=0.7, lambda=0.001
# - Fold07.Rep1: alpha=0.7, lambda=0.001
# + Fold08.Rep1: alpha=0.7, lambda=0.001
# - Fold08.Rep1: alpha=0.7, lambda=0.001
# + Fold09.Rep1: alpha=0.7, lambda=0.001
# - Fold09.Rep1: alpha=0.7, lambda=0.001
# + Fold10.Rep1: alpha=0.7, lambda=0.001
# - Fold10.Rep1: alpha=0.7, lambda=0.001
# + Fold01.Rep2: alpha=0.7, lambda=0.001
# - Fold01.Rep2: alpha=0.7, lambda=0.001
# + Fold02.Rep2: alpha=0.7, lambda=0.001
# - Fold02.Rep2: alpha=0.7, lambda=0.001
# + Fold03.Rep2: alpha=0.7, lambda=0.001
# - Fold03.Rep2: alpha=0.7, lambda=0.001
# + Fold04.Rep2: alpha=0.7, lambda=0.001
# - Fold04.Rep2: alpha=0.7, lambda=0.001
# + Fold05.Rep2: alpha=0.7, lambda=0.001
# - Fold05.Rep2: alpha=0.7, lambda=0.001
# + Fold06.Rep2: alpha=0.7, lambda=0.001
# - Fold06.Rep2: alpha=0.7, lambda=0.001
# + Fold07.Rep2: alpha=0.7, lambda=0.001
# - Fold07.Rep2: alpha=0.7, lambda=0.001
# + Fold08.Rep2: alpha=0.7, lambda=0.001
# - Fold08.Rep2: alpha=0.7, lambda=0.001
# + Fold09.Rep2: alpha=0.7, lambda=0.001
# - Fold09.Rep2: alpha=0.7, lambda=0.001
# + Fold10.Rep2: alpha=0.7, lambda=0.001
# - Fold10.Rep2: alpha=0.7, lambda=0.001
# + Fold01.Rep3: alpha=0.7, lambda=0.001
# - Fold01.Rep3: alpha=0.7, lambda=0.001
# + Fold02.Rep3: alpha=0.7, lambda=0.001
# - Fold02.Rep3: alpha=0.7, lambda=0.001
# + Fold03.Rep3: alpha=0.7, lambda=0.001
# - Fold03.Rep3: alpha=0.7, lambda=0.001
# + Fold04.Rep3: alpha=0.7, lambda=0.001
# - Fold04.Rep3: alpha=0.7, lambda=0.001
# + Fold05.Rep3: alpha=0.7, lambda=0.001
# - Fold05.Rep3: alpha=0.7, lambda=0.001
# + Fold06.Rep3: alpha=0.7, lambda=0.001
# - Fold06.Rep3: alpha=0.7, lambda=0.001
# + Fold07.Rep3: alpha=0.7, lambda=0.001
# - Fold07.Rep3: alpha=0.7, lambda=0.001
# + Fold08.Rep3: alpha=0.7, lambda=0.001
# - Fold08.Rep3: alpha=0.7, lambda=0.001
# + Fold09.Rep3: alpha=0.7, lambda=0.001
# - Fold09.Rep3: alpha=0.7, lambda=0.001
# + Fold10.Rep3: alpha=0.7, lambda=0.001
# - Fold10.Rep3: alpha=0.7, lambda=0.001
# + Fold01.Rep4: alpha=0.7, lambda=0.001
# - Fold01.Rep4: alpha=0.7, lambda=0.001
# + Fold02.Rep4: alpha=0.7, lambda=0.001
# - Fold02.Rep4: alpha=0.7, lambda=0.001
# + Fold03.Rep4: alpha=0.7, lambda=0.001
# - Fold03.Rep4: alpha=0.7, lambda=0.001
# + Fold04.Rep4: alpha=0.7, lambda=0.001
# - Fold04.Rep4: alpha=0.7, lambda=0.001
# + Fold05.Rep4: alpha=0.7, lambda=0.001
# - Fold05.Rep4: alpha=0.7, lambda=0.001
# + Fold06.Rep4: alpha=0.7, lambda=0.001
# - Fold06.Rep4: alpha=0.7, lambda=0.001
# + Fold07.Rep4: alpha=0.7, lambda=0.001
# - Fold07.Rep4: alpha=0.7, lambda=0.001
# + Fold08.Rep4: alpha=0.7, lambda=0.001
# - Fold08.Rep4: alpha=0.7, lambda=0.001
# + Fold09.Rep4: alpha=0.7, lambda=0.001
# - Fold09.Rep4: alpha=0.7, lambda=0.001
# + Fold10.Rep4: alpha=0.7, lambda=0.001
# - Fold10.Rep4: alpha=0.7, lambda=0.001
# + Fold01.Rep5: alpha=0.7, lambda=0.001
# - Fold01.Rep5: alpha=0.7, lambda=0.001
# + Fold02.Rep5: alpha=0.7, lambda=0.001
# - Fold02.Rep5: alpha=0.7, lambda=0.001
# + Fold03.Rep5: alpha=0.7, lambda=0.001
# - Fold03.Rep5: alpha=0.7, lambda=0.001
# + Fold04.Rep5: alpha=0.7, lambda=0.001
# - Fold04.Rep5: alpha=0.7, lambda=0.001
# + Fold05.Rep5: alpha=0.7, lambda=0.001
# - Fold05.Rep5: alpha=0.7, lambda=0.001
# + Fold06.Rep5: alpha=0.7, lambda=0.001
# - Fold06.Rep5: alpha=0.7, lambda=0.001
# + Fold07.Rep5: alpha=0.7, lambda=0.001
# - Fold07.Rep5: alpha=0.7, lambda=0.001
# + Fold08.Rep5: alpha=0.7, lambda=0.001
# - Fold08.Rep5: alpha=0.7, lambda=0.001
# + Fold09.Rep5: alpha=0.7, lambda=0.001
# - Fold09.Rep5: alpha=0.7, lambda=0.001
# + Fold10.Rep5: alpha=0.7, lambda=0.001
# - Fold10.Rep5: alpha=0.7, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.8, lambda=0.001
# - Fold01.Rep1: alpha=0.8, lambda=0.001
# + Fold02.Rep1: alpha=0.8, lambda=0.001
# - Fold02.Rep1: alpha=0.8, lambda=0.001
# + Fold03.Rep1: alpha=0.8, lambda=0.001
# - Fold03.Rep1: alpha=0.8, lambda=0.001
# + Fold04.Rep1: alpha=0.8, lambda=0.001
# - Fold04.Rep1: alpha=0.8, lambda=0.001
# + Fold05.Rep1: alpha=0.8, lambda=0.001
# - Fold05.Rep1: alpha=0.8, lambda=0.001
# + Fold06.Rep1: alpha=0.8, lambda=0.001
# - Fold06.Rep1: alpha=0.8, lambda=0.001
# + Fold07.Rep1: alpha=0.8, lambda=0.001
# - Fold07.Rep1: alpha=0.8, lambda=0.001
# + Fold08.Rep1: alpha=0.8, lambda=0.001
# - Fold08.Rep1: alpha=0.8, lambda=0.001
# + Fold09.Rep1: alpha=0.8, lambda=0.001
# - Fold09.Rep1: alpha=0.8, lambda=0.001
# + Fold10.Rep1: alpha=0.8, lambda=0.001
# - Fold10.Rep1: alpha=0.8, lambda=0.001
# + Fold01.Rep2: alpha=0.8, lambda=0.001
# - Fold01.Rep2: alpha=0.8, lambda=0.001
# + Fold02.Rep2: alpha=0.8, lambda=0.001
# - Fold02.Rep2: alpha=0.8, lambda=0.001
# + Fold03.Rep2: alpha=0.8, lambda=0.001
# - Fold03.Rep2: alpha=0.8, lambda=0.001
# + Fold04.Rep2: alpha=0.8, lambda=0.001
# - Fold04.Rep2: alpha=0.8, lambda=0.001
# + Fold05.Rep2: alpha=0.8, lambda=0.001
# - Fold05.Rep2: alpha=0.8, lambda=0.001
# + Fold06.Rep2: alpha=0.8, lambda=0.001
# - Fold06.Rep2: alpha=0.8, lambda=0.001
# + Fold07.Rep2: alpha=0.8, lambda=0.001
# - Fold07.Rep2: alpha=0.8, lambda=0.001
# + Fold08.Rep2: alpha=0.8, lambda=0.001
# - Fold08.Rep2: alpha=0.8, lambda=0.001
# + Fold09.Rep2: alpha=0.8, lambda=0.001
# - Fold09.Rep2: alpha=0.8, lambda=0.001
# + Fold10.Rep2: alpha=0.8, lambda=0.001
# - Fold10.Rep2: alpha=0.8, lambda=0.001
# + Fold01.Rep3: alpha=0.8, lambda=0.001
# - Fold01.Rep3: alpha=0.8, lambda=0.001
# + Fold02.Rep3: alpha=0.8, lambda=0.001
# - Fold02.Rep3: alpha=0.8, lambda=0.001
# + Fold03.Rep3: alpha=0.8, lambda=0.001
# - Fold03.Rep3: alpha=0.8, lambda=0.001
# + Fold04.Rep3: alpha=0.8, lambda=0.001
# - Fold04.Rep3: alpha=0.8, lambda=0.001
# + Fold05.Rep3: alpha=0.8, lambda=0.001
# - Fold05.Rep3: alpha=0.8, lambda=0.001
# + Fold06.Rep3: alpha=0.8, lambda=0.001
# - Fold06.Rep3: alpha=0.8, lambda=0.001
# + Fold07.Rep3: alpha=0.8, lambda=0.001
# - Fold07.Rep3: alpha=0.8, lambda=0.001
# + Fold08.Rep3: alpha=0.8, lambda=0.001
# - Fold08.Rep3: alpha=0.8, lambda=0.001
# + Fold09.Rep3: alpha=0.8, lambda=0.001
# - Fold09.Rep3: alpha=0.8, lambda=0.001
# + Fold10.Rep3: alpha=0.8, lambda=0.001
# - Fold10.Rep3: alpha=0.8, lambda=0.001
# + Fold01.Rep4: alpha=0.8, lambda=0.001
# - Fold01.Rep4: alpha=0.8, lambda=0.001
# + Fold02.Rep4: alpha=0.8, lambda=0.001
# - Fold02.Rep4: alpha=0.8, lambda=0.001
# + Fold03.Rep4: alpha=0.8, lambda=0.001
# - Fold03.Rep4: alpha=0.8, lambda=0.001
# + Fold04.Rep4: alpha=0.8, lambda=0.001
# - Fold04.Rep4: alpha=0.8, lambda=0.001
# + Fold05.Rep4: alpha=0.8, lambda=0.001
# - Fold05.Rep4: alpha=0.8, lambda=0.001
# + Fold06.Rep4: alpha=0.8, lambda=0.001
# - Fold06.Rep4: alpha=0.8, lambda=0.001
# + Fold07.Rep4: alpha=0.8, lambda=0.001
# - Fold07.Rep4: alpha=0.8, lambda=0.001
# + Fold08.Rep4: alpha=0.8, lambda=0.001
# - Fold08.Rep4: alpha=0.8, lambda=0.001
# + Fold09.Rep4: alpha=0.8, lambda=0.001
# - Fold09.Rep4: alpha=0.8, lambda=0.001
# + Fold10.Rep4: alpha=0.8, lambda=0.001
# - Fold10.Rep4: alpha=0.8, lambda=0.001
# + Fold01.Rep5: alpha=0.8, lambda=0.001
# - Fold01.Rep5: alpha=0.8, lambda=0.001
# + Fold02.Rep5: alpha=0.8, lambda=0.001
# - Fold02.Rep5: alpha=0.8, lambda=0.001
# + Fold03.Rep5: alpha=0.8, lambda=0.001
# - Fold03.Rep5: alpha=0.8, lambda=0.001
# + Fold04.Rep5: alpha=0.8, lambda=0.001
# - Fold04.Rep5: alpha=0.8, lambda=0.001
# + Fold05.Rep5: alpha=0.8, lambda=0.001
# - Fold05.Rep5: alpha=0.8, lambda=0.001
# + Fold06.Rep5: alpha=0.8, lambda=0.001
# - Fold06.Rep5: alpha=0.8, lambda=0.001
# + Fold07.Rep5: alpha=0.8, lambda=0.001
# - Fold07.Rep5: alpha=0.8, lambda=0.001
# + Fold08.Rep5: alpha=0.8, lambda=0.001
# - Fold08.Rep5: alpha=0.8, lambda=0.001
# + Fold09.Rep5: alpha=0.8, lambda=0.001
# - Fold09.Rep5: alpha=0.8, lambda=0.001
# + Fold10.Rep5: alpha=0.8, lambda=0.001
# - Fold10.Rep5: alpha=0.8, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.9, lambda=0.001
# - Fold01.Rep1: alpha=0.9, lambda=0.001
# + Fold02.Rep1: alpha=0.9, lambda=0.001
# - Fold02.Rep1: alpha=0.9, lambda=0.001
# + Fold03.Rep1: alpha=0.9, lambda=0.001
# - Fold03.Rep1: alpha=0.9, lambda=0.001
# + Fold04.Rep1: alpha=0.9, lambda=0.001
# - Fold04.Rep1: alpha=0.9, lambda=0.001
# + Fold05.Rep1: alpha=0.9, lambda=0.001
# - Fold05.Rep1: alpha=0.9, lambda=0.001
# + Fold06.Rep1: alpha=0.9, lambda=0.001
# - Fold06.Rep1: alpha=0.9, lambda=0.001
# + Fold07.Rep1: alpha=0.9, lambda=0.001
# - Fold07.Rep1: alpha=0.9, lambda=0.001
# + Fold08.Rep1: alpha=0.9, lambda=0.001
# - Fold08.Rep1: alpha=0.9, lambda=0.001
# + Fold09.Rep1: alpha=0.9, lambda=0.001
# - Fold09.Rep1: alpha=0.9, lambda=0.001
# + Fold10.Rep1: alpha=0.9, lambda=0.001
# - Fold10.Rep1: alpha=0.9, lambda=0.001
# + Fold01.Rep2: alpha=0.9, lambda=0.001
# - Fold01.Rep2: alpha=0.9, lambda=0.001
# + Fold02.Rep2: alpha=0.9, lambda=0.001
# - Fold02.Rep2: alpha=0.9, lambda=0.001
# + Fold03.Rep2: alpha=0.9, lambda=0.001
# - Fold03.Rep2: alpha=0.9, lambda=0.001
# + Fold04.Rep2: alpha=0.9, lambda=0.001
# - Fold04.Rep2: alpha=0.9, lambda=0.001
# + Fold05.Rep2: alpha=0.9, lambda=0.001
# - Fold05.Rep2: alpha=0.9, lambda=0.001
# + Fold06.Rep2: alpha=0.9, lambda=0.001
# - Fold06.Rep2: alpha=0.9, lambda=0.001
# + Fold07.Rep2: alpha=0.9, lambda=0.001
# - Fold07.Rep2: alpha=0.9, lambda=0.001
# + Fold08.Rep2: alpha=0.9, lambda=0.001
# - Fold08.Rep2: alpha=0.9, lambda=0.001
# + Fold09.Rep2: alpha=0.9, lambda=0.001
# - Fold09.Rep2: alpha=0.9, lambda=0.001
# + Fold10.Rep2: alpha=0.9, lambda=0.001
# - Fold10.Rep2: alpha=0.9, lambda=0.001
# + Fold01.Rep3: alpha=0.9, lambda=0.001
# - Fold01.Rep3: alpha=0.9, lambda=0.001
# + Fold02.Rep3: alpha=0.9, lambda=0.001
# - Fold02.Rep3: alpha=0.9, lambda=0.001
# + Fold03.Rep3: alpha=0.9, lambda=0.001
# - Fold03.Rep3: alpha=0.9, lambda=0.001
# + Fold04.Rep3: alpha=0.9, lambda=0.001
# - Fold04.Rep3: alpha=0.9, lambda=0.001
# + Fold05.Rep3: alpha=0.9, lambda=0.001
# - Fold05.Rep3: alpha=0.9, lambda=0.001
# + Fold06.Rep3: alpha=0.9, lambda=0.001
# - Fold06.Rep3: alpha=0.9, lambda=0.001
# + Fold07.Rep3: alpha=0.9, lambda=0.001
# - Fold07.Rep3: alpha=0.9, lambda=0.001
# + Fold08.Rep3: alpha=0.9, lambda=0.001
# - Fold08.Rep3: alpha=0.9, lambda=0.001
# + Fold09.Rep3: alpha=0.9, lambda=0.001
# - Fold09.Rep3: alpha=0.9, lambda=0.001
# + Fold10.Rep3: alpha=0.9, lambda=0.001
# - Fold10.Rep3: alpha=0.9, lambda=0.001
# + Fold01.Rep4: alpha=0.9, lambda=0.001
# - Fold01.Rep4: alpha=0.9, lambda=0.001
# + Fold02.Rep4: alpha=0.9, lambda=0.001
# - Fold02.Rep4: alpha=0.9, lambda=0.001
# + Fold03.Rep4: alpha=0.9, lambda=0.001
# - Fold03.Rep4: alpha=0.9, lambda=0.001
# + Fold04.Rep4: alpha=0.9, lambda=0.001
# - Fold04.Rep4: alpha=0.9, lambda=0.001
# + Fold05.Rep4: alpha=0.9, lambda=0.001
# - Fold05.Rep4: alpha=0.9, lambda=0.001
# + Fold06.Rep4: alpha=0.9, lambda=0.001
# - Fold06.Rep4: alpha=0.9, lambda=0.001
# + Fold07.Rep4: alpha=0.9, lambda=0.001
# - Fold07.Rep4: alpha=0.9, lambda=0.001
# + Fold08.Rep4: alpha=0.9, lambda=0.001
# - Fold08.Rep4: alpha=0.9, lambda=0.001
# + Fold09.Rep4: alpha=0.9, lambda=0.001
# - Fold09.Rep4: alpha=0.9, lambda=0.001
# + Fold10.Rep4: alpha=0.9, lambda=0.001
# - Fold10.Rep4: alpha=0.9, lambda=0.001
# + Fold01.Rep5: alpha=0.9, lambda=0.001
# - Fold01.Rep5: alpha=0.9, lambda=0.001
# + Fold02.Rep5: alpha=0.9, lambda=0.001
# - Fold02.Rep5: alpha=0.9, lambda=0.001
# + Fold03.Rep5: alpha=0.9, lambda=0.001
# - Fold03.Rep5: alpha=0.9, lambda=0.001
# + Fold04.Rep5: alpha=0.9, lambda=0.001
# - Fold04.Rep5: alpha=0.9, lambda=0.001
# + Fold05.Rep5: alpha=0.9, lambda=0.001
# - Fold05.Rep5: alpha=0.9, lambda=0.001
# + Fold06.Rep5: alpha=0.9, lambda=0.001
# - Fold06.Rep5: alpha=0.9, lambda=0.001
# + Fold07.Rep5: alpha=0.9, lambda=0.001
# - Fold07.Rep5: alpha=0.9, lambda=0.001
# + Fold08.Rep5: alpha=0.9, lambda=0.001
# - Fold08.Rep5: alpha=0.9, lambda=0.001
# + Fold09.Rep5: alpha=0.9, lambda=0.001
# - Fold09.Rep5: alpha=0.9, lambda=0.001
# + Fold10.Rep5: alpha=0.9, lambda=0.001
# - Fold10.Rep5: alpha=0.9, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=1, lambda=0.001
# - Fold01.Rep1: alpha=1, lambda=0.001
# + Fold02.Rep1: alpha=1, lambda=0.001
# - Fold02.Rep1: alpha=1, lambda=0.001
# + Fold03.Rep1: alpha=1, lambda=0.001
# - Fold03.Rep1: alpha=1, lambda=0.001
# + Fold04.Rep1: alpha=1, lambda=0.001
# - Fold04.Rep1: alpha=1, lambda=0.001
# + Fold05.Rep1: alpha=1, lambda=0.001
# - Fold05.Rep1: alpha=1, lambda=0.001
# + Fold06.Rep1: alpha=1, lambda=0.001
# - Fold06.Rep1: alpha=1, lambda=0.001
# + Fold07.Rep1: alpha=1, lambda=0.001
# - Fold07.Rep1: alpha=1, lambda=0.001
# + Fold08.Rep1: alpha=1, lambda=0.001
# - Fold08.Rep1: alpha=1, lambda=0.001
# + Fold09.Rep1: alpha=1, lambda=0.001
# - Fold09.Rep1: alpha=1, lambda=0.001
# + Fold10.Rep1: alpha=1, lambda=0.001
# - Fold10.Rep1: alpha=1, lambda=0.001
# + Fold01.Rep2: alpha=1, lambda=0.001
# - Fold01.Rep2: alpha=1, lambda=0.001
# + Fold02.Rep2: alpha=1, lambda=0.001
# - Fold02.Rep2: alpha=1, lambda=0.001
# + Fold03.Rep2: alpha=1, lambda=0.001
# - Fold03.Rep2: alpha=1, lambda=0.001
# + Fold04.Rep2: alpha=1, lambda=0.001
# - Fold04.Rep2: alpha=1, lambda=0.001
# + Fold05.Rep2: alpha=1, lambda=0.001
# - Fold05.Rep2: alpha=1, lambda=0.001
# + Fold06.Rep2: alpha=1, lambda=0.001
# - Fold06.Rep2: alpha=1, lambda=0.001
# + Fold07.Rep2: alpha=1, lambda=0.001
# - Fold07.Rep2: alpha=1, lambda=0.001
# + Fold08.Rep2: alpha=1, lambda=0.001
# - Fold08.Rep2: alpha=1, lambda=0.001
# + Fold09.Rep2: alpha=1, lambda=0.001
# - Fold09.Rep2: alpha=1, lambda=0.001
# + Fold10.Rep2: alpha=1, lambda=0.001
# - Fold10.Rep2: alpha=1, lambda=0.001
# + Fold01.Rep3: alpha=1, lambda=0.001
# - Fold01.Rep3: alpha=1, lambda=0.001
# + Fold02.Rep3: alpha=1, lambda=0.001
# - Fold02.Rep3: alpha=1, lambda=0.001
# + Fold03.Rep3: alpha=1, lambda=0.001
# - Fold03.Rep3: alpha=1, lambda=0.001
# + Fold04.Rep3: alpha=1, lambda=0.001
# - Fold04.Rep3: alpha=1, lambda=0.001
# + Fold05.Rep3: alpha=1, lambda=0.001
# - Fold05.Rep3: alpha=1, lambda=0.001
# + Fold06.Rep3: alpha=1, lambda=0.001
# - Fold06.Rep3: alpha=1, lambda=0.001
# + Fold07.Rep3: alpha=1, lambda=0.001
# - Fold07.Rep3: alpha=1, lambda=0.001
# + Fold08.Rep3: alpha=1, lambda=0.001
# - Fold08.Rep3: alpha=1, lambda=0.001
# + Fold09.Rep3: alpha=1, lambda=0.001
# - Fold09.Rep3: alpha=1, lambda=0.001
# + Fold10.Rep3: alpha=1, lambda=0.001
# - Fold10.Rep3: alpha=1, lambda=0.001
# + Fold01.Rep4: alpha=1, lambda=0.001
# - Fold01.Rep4: alpha=1, lambda=0.001
# + Fold02.Rep4: alpha=1, lambda=0.001
# - Fold02.Rep4: alpha=1, lambda=0.001
# + Fold03.Rep4: alpha=1, lambda=0.001
# - Fold03.Rep4: alpha=1, lambda=0.001
# + Fold04.Rep4: alpha=1, lambda=0.001
# - Fold04.Rep4: alpha=1, lambda=0.001
# + Fold05.Rep4: alpha=1, lambda=0.001
# - Fold05.Rep4: alpha=1, lambda=0.001
# + Fold06.Rep4: alpha=1, lambda=0.001
# - Fold06.Rep4: alpha=1, lambda=0.001
# + Fold07.Rep4: alpha=1, lambda=0.001
# - Fold07.Rep4: alpha=1, lambda=0.001
# + Fold08.Rep4: alpha=1, lambda=0.001
# - Fold08.Rep4: alpha=1, lambda=0.001
# + Fold09.Rep4: alpha=1, lambda=0.001
# - Fold09.Rep4: alpha=1, lambda=0.001
# + Fold10.Rep4: alpha=1, lambda=0.001
# - Fold10.Rep4: alpha=1, lambda=0.001
# + Fold01.Rep5: alpha=1, lambda=0.001
# - Fold01.Rep5: alpha=1, lambda=0.001
# + Fold02.Rep5: alpha=1, lambda=0.001
# - Fold02.Rep5: alpha=1, lambda=0.001
# + Fold03.Rep5: alpha=1, lambda=0.001
# - Fold03.Rep5: alpha=1, lambda=0.001
# + Fold04.Rep5: alpha=1, lambda=0.001
# - Fold04.Rep5: alpha=1, lambda=0.001
# + Fold05.Rep5: alpha=1, lambda=0.001
# - Fold05.Rep5: alpha=1, lambda=0.001
# + Fold06.Rep5: alpha=1, lambda=0.001
# - Fold06.Rep5: alpha=1, lambda=0.001
# + Fold07.Rep5: alpha=1, lambda=0.001
# - Fold07.Rep5: alpha=1, lambda=0.001
# + Fold08.Rep5: alpha=1, lambda=0.001
# - Fold08.Rep5: alpha=1, lambda=0.001
# + Fold09.Rep5: alpha=1, lambda=0.001
# - Fold09.Rep5: alpha=1, lambda=0.001
# + Fold10.Rep5: alpha=1, lambda=0.001
# - Fold10.Rep5: alpha=1, lambda=0.001
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0, lambda=0.101
# - Fold01.Rep1: alpha=0, lambda=0.101
# + Fold02.Rep1: alpha=0, lambda=0.101
# - Fold02.Rep1: alpha=0, lambda=0.101
# + Fold03.Rep1: alpha=0, lambda=0.101
# - Fold03.Rep1: alpha=0, lambda=0.101
# + Fold04.Rep1: alpha=0, lambda=0.101
# - Fold04.Rep1: alpha=0, lambda=0.101
# + Fold05.Rep1: alpha=0, lambda=0.101
# - Fold05.Rep1: alpha=0, lambda=0.101
# + Fold06.Rep1: alpha=0, lambda=0.101
# - Fold06.Rep1: alpha=0, lambda=0.101
# + Fold07.Rep1: alpha=0, lambda=0.101
# - Fold07.Rep1: alpha=0, lambda=0.101
# + Fold08.Rep1: alpha=0, lambda=0.101
# - Fold08.Rep1: alpha=0, lambda=0.101
# + Fold09.Rep1: alpha=0, lambda=0.101
# - Fold09.Rep1: alpha=0, lambda=0.101
# + Fold10.Rep1: alpha=0, lambda=0.101
# - Fold10.Rep1: alpha=0, lambda=0.101
# + Fold01.Rep2: alpha=0, lambda=0.101
# - Fold01.Rep2: alpha=0, lambda=0.101
# + Fold02.Rep2: alpha=0, lambda=0.101
# - Fold02.Rep2: alpha=0, lambda=0.101
# + Fold03.Rep2: alpha=0, lambda=0.101
# - Fold03.Rep2: alpha=0, lambda=0.101
# ...
# + Fold08.Rep2: alpha=0.7, lambda=0.901
# - Fold08.Rep2: alpha=0.7, lambda=0.901
# + Fold09.Rep2: alpha=0.7, lambda=0.901
# - Fold09.Rep2: alpha=0.7, lambda=0.901
# + Fold10.Rep2: alpha=0.7, lambda=0.901
# - Fold10.Rep2: alpha=0.7, lambda=0.901
# + Fold01.Rep3: alpha=0.7, lambda=0.901
# - Fold01.Rep3: alpha=0.7, lambda=0.901
# + Fold02.Rep3: alpha=0.7, lambda=0.901
# - Fold02.Rep3: alpha=0.7, lambda=0.901
# + Fold03.Rep3: alpha=0.7, lambda=0.901
# - Fold03.Rep3: alpha=0.7, lambda=0.901
# + Fold04.Rep3: alpha=0.7, lambda=0.901
# - Fold04.Rep3: alpha=0.7, lambda=0.901
# + Fold05.Rep3: alpha=0.7, lambda=0.901
# - Fold05.Rep3: alpha=0.7, lambda=0.901
# + Fold06.Rep3: alpha=0.7, lambda=0.901
# - Fold06.Rep3: alpha=0.7, lambda=0.901
# + Fold07.Rep3: alpha=0.7, lambda=0.901
# - Fold07.Rep3: alpha=0.7, lambda=0.901
# + Fold08.Rep3: alpha=0.7, lambda=0.901
# - Fold08.Rep3: alpha=0.7, lambda=0.901
# + Fold09.Rep3: alpha=0.7, lambda=0.901
# - Fold09.Rep3: alpha=0.7, lambda=0.901
# + Fold10.Rep3: alpha=0.7, lambda=0.901
# - Fold10.Rep3: alpha=0.7, lambda=0.901
# + Fold01.Rep4: alpha=0.7, lambda=0.901
# - Fold01.Rep4: alpha=0.7, lambda=0.901
# + Fold02.Rep4: alpha=0.7, lambda=0.901
# - Fold02.Rep4: alpha=0.7, lambda=0.901
# + Fold03.Rep4: alpha=0.7, lambda=0.901
# - Fold03.Rep4: alpha=0.7, lambda=0.901
# + Fold04.Rep4: alpha=0.7, lambda=0.901
# - Fold04.Rep4: alpha=0.7, lambda=0.901
# + Fold05.Rep4: alpha=0.7, lambda=0.901
# - Fold05.Rep4: alpha=0.7, lambda=0.901
# + Fold06.Rep4: alpha=0.7, lambda=0.901
# - Fold06.Rep4: alpha=0.7, lambda=0.901
# + Fold07.Rep4: alpha=0.7, lambda=0.901
# - Fold07.Rep4: alpha=0.7, lambda=0.901
# + Fold08.Rep4: alpha=0.7, lambda=0.901
# - Fold08.Rep4: alpha=0.7, lambda=0.901
# + Fold09.Rep4: alpha=0.7, lambda=0.901
# - Fold09.Rep4: alpha=0.7, lambda=0.901
# + Fold10.Rep4: alpha=0.7, lambda=0.901
# - Fold10.Rep4: alpha=0.7, lambda=0.901
# + Fold01.Rep5: alpha=0.7, lambda=0.901
# - Fold01.Rep5: alpha=0.7, lambda=0.901
# + Fold02.Rep5: alpha=0.7, lambda=0.901
# - Fold02.Rep5: alpha=0.7, lambda=0.901
# + Fold03.Rep5: alpha=0.7, lambda=0.901
# - Fold03.Rep5: alpha=0.7, lambda=0.901
# + Fold04.Rep5: alpha=0.7, lambda=0.901
# - Fold04.Rep5: alpha=0.7, lambda=0.901
# + Fold05.Rep5: alpha=0.7, lambda=0.901
# - Fold05.Rep5: alpha=0.7, lambda=0.901
# + Fold06.Rep5: alpha=0.7, lambda=0.901
# - Fold06.Rep5: alpha=0.7, lambda=0.901
# + Fold07.Rep5: alpha=0.7, lambda=0.901
# - Fold07.Rep5: alpha=0.7, lambda=0.901
# + Fold08.Rep5: alpha=0.7, lambda=0.901
# - Fold08.Rep5: alpha=0.7, lambda=0.901
# + Fold09.Rep5: alpha=0.7, lambda=0.901
# - Fold09.Rep5: alpha=0.7, lambda=0.901
# + Fold10.Rep5: alpha=0.7, lambda=0.901
# - Fold10.Rep5: alpha=0.7, lambda=0.901
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.8, lambda=0.901
# - Fold01.Rep1: alpha=0.8, lambda=0.901
# + Fold02.Rep1: alpha=0.8, lambda=0.901
# - Fold02.Rep1: alpha=0.8, lambda=0.901
# + Fold03.Rep1: alpha=0.8, lambda=0.901
# - Fold03.Rep1: alpha=0.8, lambda=0.901
# + Fold04.Rep1: alpha=0.8, lambda=0.901
# - Fold04.Rep1: alpha=0.8, lambda=0.901
# + Fold05.Rep1: alpha=0.8, lambda=0.901
# - Fold05.Rep1: alpha=0.8, lambda=0.901
# + Fold06.Rep1: alpha=0.8, lambda=0.901
# - Fold06.Rep1: alpha=0.8, lambda=0.901
# + Fold07.Rep1: alpha=0.8, lambda=0.901
# - Fold07.Rep1: alpha=0.8, lambda=0.901
# + Fold08.Rep1: alpha=0.8, lambda=0.901
# - Fold08.Rep1: alpha=0.8, lambda=0.901
# + Fold09.Rep1: alpha=0.8, lambda=0.901
# - Fold09.Rep1: alpha=0.8, lambda=0.901
# + Fold10.Rep1: alpha=0.8, lambda=0.901
# - Fold10.Rep1: alpha=0.8, lambda=0.901
# + Fold01.Rep2: alpha=0.8, lambda=0.901
# - Fold01.Rep2: alpha=0.8, lambda=0.901
# + Fold02.Rep2: alpha=0.8, lambda=0.901
# - Fold02.Rep2: alpha=0.8, lambda=0.901
# + Fold03.Rep2: alpha=0.8, lambda=0.901
# - Fold03.Rep2: alpha=0.8, lambda=0.901
# + Fold04.Rep2: alpha=0.8, lambda=0.901
# - Fold04.Rep2: alpha=0.8, lambda=0.901
# + Fold05.Rep2: alpha=0.8, lambda=0.901
# - Fold05.Rep2: alpha=0.8, lambda=0.901
# + Fold06.Rep2: alpha=0.8, lambda=0.901
# - Fold06.Rep2: alpha=0.8, lambda=0.901
# + Fold07.Rep2: alpha=0.8, lambda=0.901
# - Fold07.Rep2: alpha=0.8, lambda=0.901
# + Fold08.Rep2: alpha=0.8, lambda=0.901
# - Fold08.Rep2: alpha=0.8, lambda=0.901
# + Fold09.Rep2: alpha=0.8, lambda=0.901
# - Fold09.Rep2: alpha=0.8, lambda=0.901
# + Fold10.Rep2: alpha=0.8, lambda=0.901
# - Fold10.Rep2: alpha=0.8, lambda=0.901
# + Fold01.Rep3: alpha=0.8, lambda=0.901
# - Fold01.Rep3: alpha=0.8, lambda=0.901
# + Fold02.Rep3: alpha=0.8, lambda=0.901
# - Fold02.Rep3: alpha=0.8, lambda=0.901
# + Fold03.Rep3: alpha=0.8, lambda=0.901
# - Fold03.Rep3: alpha=0.8, lambda=0.901
# + Fold04.Rep3: alpha=0.8, lambda=0.901
# - Fold04.Rep3: alpha=0.8, lambda=0.901
# + Fold05.Rep3: alpha=0.8, lambda=0.901
# - Fold05.Rep3: alpha=0.8, lambda=0.901
# + Fold06.Rep3: alpha=0.8, lambda=0.901
# - Fold06.Rep3: alpha=0.8, lambda=0.901
# + Fold07.Rep3: alpha=0.8, lambda=0.901
# - Fold07.Rep3: alpha=0.8, lambda=0.901
# + Fold08.Rep3: alpha=0.8, lambda=0.901
# - Fold08.Rep3: alpha=0.8, lambda=0.901
# + Fold09.Rep3: alpha=0.8, lambda=0.901
# - Fold09.Rep3: alpha=0.8, lambda=0.901
# + Fold10.Rep3: alpha=0.8, lambda=0.901
# - Fold10.Rep3: alpha=0.8, lambda=0.901
# + Fold01.Rep4: alpha=0.8, lambda=0.901
# - Fold01.Rep4: alpha=0.8, lambda=0.901
# + Fold02.Rep4: alpha=0.8, lambda=0.901
# - Fold02.Rep4: alpha=0.8, lambda=0.901
# + Fold03.Rep4: alpha=0.8, lambda=0.901
# - Fold03.Rep4: alpha=0.8, lambda=0.901
# + Fold04.Rep4: alpha=0.8, lambda=0.901
# - Fold04.Rep4: alpha=0.8, lambda=0.901
# + Fold05.Rep4: alpha=0.8, lambda=0.901
# - Fold05.Rep4: alpha=0.8, lambda=0.901
# + Fold06.Rep4: alpha=0.8, lambda=0.901
# - Fold06.Rep4: alpha=0.8, lambda=0.901
# + Fold07.Rep4: alpha=0.8, lambda=0.901
# - Fold07.Rep4: alpha=0.8, lambda=0.901
# + Fold08.Rep4: alpha=0.8, lambda=0.901
# - Fold08.Rep4: alpha=0.8, lambda=0.901
# + Fold09.Rep4: alpha=0.8, lambda=0.901
# - Fold09.Rep4: alpha=0.8, lambda=0.901
# + Fold10.Rep4: alpha=0.8, lambda=0.901
# - Fold10.Rep4: alpha=0.8, lambda=0.901
# + Fold01.Rep5: alpha=0.8, lambda=0.901
# - Fold01.Rep5: alpha=0.8, lambda=0.901
# + Fold02.Rep5: alpha=0.8, lambda=0.901
# - Fold02.Rep5: alpha=0.8, lambda=0.901
# + Fold03.Rep5: alpha=0.8, lambda=0.901
# - Fold03.Rep5: alpha=0.8, lambda=0.901
# + Fold04.Rep5: alpha=0.8, lambda=0.901
# - Fold04.Rep5: alpha=0.8, lambda=0.901
# + Fold05.Rep5: alpha=0.8, lambda=0.901
# - Fold05.Rep5: alpha=0.8, lambda=0.901
# + Fold06.Rep5: alpha=0.8, lambda=0.901
# - Fold06.Rep5: alpha=0.8, lambda=0.901
# + Fold07.Rep5: alpha=0.8, lambda=0.901
# - Fold07.Rep5: alpha=0.8, lambda=0.901
# + Fold08.Rep5: alpha=0.8, lambda=0.901
# - Fold08.Rep5: alpha=0.8, lambda=0.901
# + Fold09.Rep5: alpha=0.8, lambda=0.901
# - Fold09.Rep5: alpha=0.8, lambda=0.901
# + Fold10.Rep5: alpha=0.8, lambda=0.901
# - Fold10.Rep5: alpha=0.8, lambda=0.901
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=0.9, lambda=0.901
# - Fold01.Rep1: alpha=0.9, lambda=0.901
# + Fold02.Rep1: alpha=0.9, lambda=0.901
# - Fold02.Rep1: alpha=0.9, lambda=0.901
# + Fold03.Rep1: alpha=0.9, lambda=0.901
# - Fold03.Rep1: alpha=0.9, lambda=0.901
# + Fold04.Rep1: alpha=0.9, lambda=0.901
# - Fold04.Rep1: alpha=0.9, lambda=0.901
# + Fold05.Rep1: alpha=0.9, lambda=0.901
# - Fold05.Rep1: alpha=0.9, lambda=0.901
# + Fold06.Rep1: alpha=0.9, lambda=0.901
# - Fold06.Rep1: alpha=0.9, lambda=0.901
# + Fold07.Rep1: alpha=0.9, lambda=0.901
# - Fold07.Rep1: alpha=0.9, lambda=0.901
# + Fold08.Rep1: alpha=0.9, lambda=0.901
# - Fold08.Rep1: alpha=0.9, lambda=0.901
# + Fold09.Rep1: alpha=0.9, lambda=0.901
# - Fold09.Rep1: alpha=0.9, lambda=0.901
# + Fold10.Rep1: alpha=0.9, lambda=0.901
# - Fold10.Rep1: alpha=0.9, lambda=0.901
# + Fold01.Rep2: alpha=0.9, lambda=0.901
# - Fold01.Rep2: alpha=0.9, lambda=0.901
# + Fold02.Rep2: alpha=0.9, lambda=0.901
# - Fold02.Rep2: alpha=0.9, lambda=0.901
# + Fold03.Rep2: alpha=0.9, lambda=0.901
# - Fold03.Rep2: alpha=0.9, lambda=0.901
# + Fold04.Rep2: alpha=0.9, lambda=0.901
# - Fold04.Rep2: alpha=0.9, lambda=0.901
# + Fold05.Rep2: alpha=0.9, lambda=0.901
# - Fold05.Rep2: alpha=0.9, lambda=0.901
# + Fold06.Rep2: alpha=0.9, lambda=0.901
# - Fold06.Rep2: alpha=0.9, lambda=0.901
# + Fold07.Rep2: alpha=0.9, lambda=0.901
# - Fold07.Rep2: alpha=0.9, lambda=0.901
# + Fold08.Rep2: alpha=0.9, lambda=0.901
# - Fold08.Rep2: alpha=0.9, lambda=0.901
# + Fold09.Rep2: alpha=0.9, lambda=0.901
# - Fold09.Rep2: alpha=0.9, lambda=0.901
# + Fold10.Rep2: alpha=0.9, lambda=0.901
# - Fold10.Rep2: alpha=0.9, lambda=0.901
# + Fold01.Rep3: alpha=0.9, lambda=0.901
# - Fold01.Rep3: alpha=0.9, lambda=0.901
# + Fold02.Rep3: alpha=0.9, lambda=0.901
# - Fold02.Rep3: alpha=0.9, lambda=0.901
# + Fold03.Rep3: alpha=0.9, lambda=0.901
# - Fold03.Rep3: alpha=0.9, lambda=0.901
# + Fold04.Rep3: alpha=0.9, lambda=0.901
# - Fold04.Rep3: alpha=0.9, lambda=0.901
# + Fold05.Rep3: alpha=0.9, lambda=0.901
# - Fold05.Rep3: alpha=0.9, lambda=0.901
# + Fold06.Rep3: alpha=0.9, lambda=0.901
# - Fold06.Rep3: alpha=0.9, lambda=0.901
# + Fold07.Rep3: alpha=0.9, lambda=0.901
# - Fold07.Rep3: alpha=0.9, lambda=0.901
# + Fold08.Rep3: alpha=0.9, lambda=0.901
# - Fold08.Rep3: alpha=0.9, lambda=0.901
# + Fold09.Rep3: alpha=0.9, lambda=0.901
# - Fold09.Rep3: alpha=0.9, lambda=0.901
# + Fold10.Rep3: alpha=0.9, lambda=0.901
# - Fold10.Rep3: alpha=0.9, lambda=0.901
# + Fold01.Rep4: alpha=0.9, lambda=0.901
# - Fold01.Rep4: alpha=0.9, lambda=0.901
# + Fold02.Rep4: alpha=0.9, lambda=0.901
# - Fold02.Rep4: alpha=0.9, lambda=0.901
# + Fold03.Rep4: alpha=0.9, lambda=0.901
# - Fold03.Rep4: alpha=0.9, lambda=0.901
# + Fold04.Rep4: alpha=0.9, lambda=0.901
# - Fold04.Rep4: alpha=0.9, lambda=0.901
# + Fold05.Rep4: alpha=0.9, lambda=0.901
# - Fold05.Rep4: alpha=0.9, lambda=0.901
# + Fold06.Rep4: alpha=0.9, lambda=0.901
# - Fold06.Rep4: alpha=0.9, lambda=0.901
# + Fold07.Rep4: alpha=0.9, lambda=0.901
# - Fold07.Rep4: alpha=0.9, lambda=0.901
# + Fold08.Rep4: alpha=0.9, lambda=0.901
# - Fold08.Rep4: alpha=0.9, lambda=0.901
# + Fold09.Rep4: alpha=0.9, lambda=0.901
# - Fold09.Rep4: alpha=0.9, lambda=0.901
# + Fold10.Rep4: alpha=0.9, lambda=0.901
# - Fold10.Rep4: alpha=0.9, lambda=0.901
# + Fold01.Rep5: alpha=0.9, lambda=0.901
# - Fold01.Rep5: alpha=0.9, lambda=0.901
# + Fold02.Rep5: alpha=0.9, lambda=0.901
# - Fold02.Rep5: alpha=0.9, lambda=0.901
# + Fold03.Rep5: alpha=0.9, lambda=0.901
# - Fold03.Rep5: alpha=0.9, lambda=0.901
# + Fold04.Rep5: alpha=0.9, lambda=0.901
# - Fold04.Rep5: alpha=0.9, lambda=0.901
# + Fold05.Rep5: alpha=0.9, lambda=0.901
# - Fold05.Rep5: alpha=0.9, lambda=0.901
# + Fold06.Rep5: alpha=0.9, lambda=0.901
# - Fold06.Rep5: alpha=0.9, lambda=0.901
# + Fold07.Rep5: alpha=0.9, lambda=0.901
# - Fold07.Rep5: alpha=0.9, lambda=0.901
# + Fold08.Rep5: alpha=0.9, lambda=0.901
# - Fold08.Rep5: alpha=0.9, lambda=0.901
# + Fold09.Rep5: alpha=0.9, lambda=0.901
# - Fold09.Rep5: alpha=0.9, lambda=0.901
# + Fold10.Rep5: alpha=0.9, lambda=0.901
# - Fold10.Rep5: alpha=0.9, lambda=0.901
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Aggregating results
# Fitting final model on full training set
# Warning message in train.default(x, y, weights = w, ...):
# “You are trying to do regression and your outcome only has two possible values Are you trying to do classification? If so, use a 2 level factor as your outcome column.”
# + Fold01.Rep1: alpha=1, lambda=0.901
# - Fold01.Rep1: alpha=1, lambda=0.901
# + Fold02.Rep1: alpha=1, lambda=0.901
# - Fold02.Rep1: alpha=1, lambda=0.901
# + Fold03.Rep1: alpha=1, lambda=0.901
# - Fold03.Rep1: alpha=1, lambda=0.901
# + Fold04.Rep1: alpha=1, lambda=0.901
# - Fold04.Rep1: alpha=1, lambda=0.901
# + Fold05.Rep1: alpha=1, lambda=0.901
# - Fold05.Rep1: alpha=1, lambda=0.901
# + Fold06.Rep1: alpha=1, lambda=0.901
# - Fold06.Rep1: alpha=1, lambda=0.901
# + Fold07.Rep1: alpha=1, lambda=0.901
# - Fold07.Rep1: alpha=1, lambda=0.901
# + Fold08.Rep1: alpha=1, lambda=0.901
# - Fold08.Rep1: alpha=1, lambda=0.901
# + Fold09.Rep1: alpha=1, lambda=0.901
# - Fold09.Rep1: alpha=1, lambda=0.901
# + Fold10.Rep1: alpha=1, lambda=0.901
# - Fold10.Rep1: alpha=1, lambda=0.901
# + Fold01.Rep2: alpha=1, lambda=0.901
# - Fold01.Rep2: alpha=1, lambda=0.901
# + Fold02.Rep2: alpha=1, lambda=0.901
# - Fold02.Rep2: alpha=1, lambda=0.901
# + Fold03.Rep2: alpha=1, lambda=0.901
# - Fold03.Rep2: alpha=1, lambda=0.901
# + Fold04.Rep2: alpha=1, lambda=0.901
# - Fold04.Rep2: alpha=1, lambda=0.901
# + Fold05.Rep2: alpha=1, lambda=0.901
# - Fold05.Rep2: alpha=1, lambda=0.901
# + Fold06.Rep2: alpha=1, lambda=0.901
# - Fold06.Rep2: alpha=1, lambda=0.901
# + Fold07.Rep2: alpha=1, lambda=0.901
# - Fold07.Rep2: alpha=1, lambda=0.901
# + Fold08.Rep2: alpha=1, lambda=0.901
# - Fold08.Rep2: alpha=1, lambda=0.901
# + Fold09.Rep2: alpha=1, lambda=0.901
# - Fold09.Rep2: alpha=1, lambda=0.901
# + Fold10.Rep2: alpha=1, lambda=0.901
# - Fold10.Rep2: alpha=1, lambda=0.901
# + Fold01.Rep3: alpha=1, lambda=0.901
# - Fold01.Rep3: alpha=1, lambda=0.901
# + Fold02.Rep3: alpha=1, lambda=0.901
# - Fold02.Rep3: alpha=1, lambda=0.901
# + Fold03.Rep3: alpha=1, lambda=0.901
# - Fold03.Rep3: alpha=1, lambda=0.901
# + Fold04.Rep3: alpha=1, lambda=0.901
# - Fold04.Rep3: alpha=1, lambda=0.901
# + Fold05.Rep3: alpha=1, lambda=0.901
# - Fold05.Rep3: alpha=1, lambda=0.901
# + Fold06.Rep3: alpha=1, lambda=0.901
# - Fold06.Rep3: alpha=1, lambda=0.901
# + Fold07.Rep3: alpha=1, lambda=0.901
# - Fold07.Rep3: alpha=1, lambda=0.901
# + Fold08.Rep3: alpha=1, lambda=0.901
# - Fold08.Rep3: alpha=1, lambda=0.901
# + Fold09.Rep3: alpha=1, lambda=0.901
# - Fold09.Rep3: alpha=1, lambda=0.901
# + Fold10.Rep3: alpha=1, lambda=0.901
# - Fold10.Rep3: alpha=1, lambda=0.901
# + Fold01.Rep4: alpha=1, lambda=0.901
# - Fold01.Rep4: alpha=1, lambda=0.901
# + Fold02.Rep4: alpha=1, lambda=0.901
# - Fold02.Rep4: alpha=1, lambda=0.901
# + Fold03.Rep4: alpha=1, lambda=0.901
# - Fold03.Rep4: alpha=1, lambda=0.901
# + Fold04.Rep4: alpha=1, lambda=0.901
# - Fold04.Rep4: alpha=1, lambda=0.901
# + Fold05.Rep4: alpha=1, lambda=0.901
# - Fold05.Rep4: alpha=1, lambda=0.901
# + Fold06.Rep4: alpha=1, lambda=0.901
# - Fold06.Rep4: alpha=1, lambda=0.901
# + Fold07.Rep4: alpha=1, lambda=0.901
# - Fold07.Rep4: alpha=1, lambda=0.901
# + Fold08.Rep4: alpha=1, lambda=0.901
# - Fold08.Rep4: alpha=1, lambda=0.901
# + Fold09.Rep4: alpha=1, lambda=0.901
# - Fold09.Rep4: alpha=1, lambda=0.901
# + Fold10.Rep4: alpha=1, lambda=0.901
# - Fold10.Rep4: alpha=1, lambda=0.901
# + Fold01.Rep5: alpha=1, lambda=0.901
# - Fold01.Rep5: alpha=1, lambda=0.901
# + Fold02.Rep5: alpha=1, lambda=0.901
# - Fold02.Rep5: alpha=1, lambda=0.901
# + Fold03.Rep5: alpha=1, lambda=0.901
# - Fold03.Rep5: alpha=1, lambda=0.901
# + Fold04.Rep5: alpha=1, lambda=0.901
# - Fold04.Rep5: alpha=1, lambda=0.901
# + Fold05.Rep5: alpha=1, lambda=0.901
# - Fold05.Rep5: alpha=1, lambda=0.901
# + Fold06.Rep5: alpha=1, lambda=0.901
# - Fold06.Rep5: alpha=1, lambda=0.901
# + Fold07.Rep5: alpha=1, lambda=0.901
# - Fold07.Rep5: alpha=1, lambda=0.901
# + Fold08.Rep5: alpha=1, lambda=0.901
# - Fold08.Rep5: alpha=1, lambda=0.901
# + Fold09.Rep5: alpha=1, lambda=0.901
# - Fold09.Rep5: alpha=1, lambda=0.901
# + Fold10.Rep5: alpha=1, lambda=0.901
# - Fold10.Rep5: alpha=1, lambda=0.901
# Warning message in nominalTrainWorkflow(x = x, y = y, wts = weights, info = trainInfo, :
# “There were missing values in resampled performance measures.”
# Aggregating results
# Fitting final model on full training set

# %%
# Convertinf MSE values to a data frame for plotting
mse_data <- expand.grid(alpha = alphas, lambda = lambdas)
mse_data$MSE <- as.vector(mse_values)

# Plotting
ggplot(mse_data, aes(x = alpha, y = lambda, fill = MSE)) +
  geom_tile() +
  scale_fill_gradient(low = "white", high = "blue") +
  labs(title = "MSE values across Alphas/Lambdas", x = "Alphas", y = "Lambdas") +
  theme_minimal()
# Out:
# plot without title

# %%
# Find the best alpha and lambda based on minimum MSE
best_index <- which(mse_data$MSE == min(mse_data$MSE))
best_alpha <- mse_data$alpha[best_index]
best_lambda <- mse_data$lambda[best_index]

# print best alpha and best lambda
cat("Best Alpha:", best_alpha, "\n")
cat("Best Lambda:", best_lambda, "\n")

# Set up the model with the best alpha and lambda
final_model <- glmnet(x = X_train, y = y_train, alpha = best_alpha, lambda = best_lambda)
# Out:
# Best Alpha: 0.2
# Best Lambda: 0.101

# %%
# Make predictions
predictions <- predict(final_model, newx = X_test, s = best_lambda)

# Mean Squared Error
mse <- mean((predictions - y_test)^2)
print(paste("Mean Squared Error on Test Set:", mse))

# Convert predictions to binary
threshold <- 0.5
binary_predictions <- ifelse(predictions > threshold, 1, 0)

# Confusion Matrix
conf_matrix <- table(binary_predictions, y_test)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# [1] "Mean Squared Error on Test Set: 0.065355324707686"
# [1] "Confusion Matrix:"
#                   y_test
# binary_predictions    0    1
#                  0 6387  501
#                  1  771 6657

# %%
# Calculate accuracy
accuracy <- sum(diag(conf_matrix)) / sum(conf_matrix)
print(paste("Accuracy:", accuracy))

# Precision
precision <- conf_matrix[2, 2] / sum(conf_matrix[, 2])
print(paste("Precision:", precision))

# Recall
recall <- conf_matrix[2, 2] / sum(conf_matrix[2, ])
print(paste("Recall:", recall))
# Out:
# [1] "Accuracy: 0.911148365465214"
# [1] "Precision: 0.930008382229673"
# [1] "Recall: 0.896203554119548"

# %% [markdown]
# # Sparse SVM with Lasso regularization

# %%
# Rename the datasets -> we use the whole X_train for the cv, it is fast and has way better results
X_cv <- X_train
y_cv <- y_train

# Adjust type
X_cv <- as.matrix(X_cv)
y_cv <- as.vector(y_cv)

lasso.svm <- sparseSVM(X_cv, y_cv)
plot(lasso.svm, xvar="norm")
plot(lasso.svm, xvar="lambda")

# Fit Lasso Sparse SVM Model with Cross-Validation
cv.svm <- cv.sparseSVM(X_cv, y_cv)

# Extract the best lamda
plot(cv.svm)
cat("Lambda min:", cv.svm$lambda.min, "\n")

# Refit the model with the optimal cost parameter
final_svm_model <- sparseSVM(as.matrix(X_train),as.vector(y_train),lambda = cv.svm$lambda.min)

# Predict on the test data
svm_predictions <- as.vector(predict(final_svm_model, X = as.matrix(X_test)))

# Mean Squared Error
svm_mse <- mean((svm_predictions - y_test)^2)
print(paste("Mean Squared Error on Test Set:", svm_mse))
# Out:
# plot without title
# plot without title
# Lambda min: 0.3578285
# [1] "Mean Squared Error on Test Set: 0.139354568315172"
# plot without title

# %%
# Convert predictions to binary (e.g., using a threshold)
threshold <- 0.5
svm_binary_predictions <- ifelse(svm_predictions > threshold, 1, 0)

# Calculate confusion matrix
svm_conf_matrix <- table(svm_binary_predictions, y_test)
print("Confusion Matrix:")
print(svm_conf_matrix)

# Calculate accuracy
svm_accuracy <- sum(diag(svm_conf_matrix)) / sum(svm_conf_matrix)
print(paste("Accuracy:", svm_accuracy))

# Precision
svm_precision <- svm_conf_matrix[2, 2] / sum(svm_conf_matrix[, 2])
print(paste("Precision:", svm_precision))

# Recall
svm_recall <- svm_conf_matrix[2, 2] / sum(svm_conf_matrix[2, ])
print(paste("Recall:", svm_recall))
# Out:
# [1] "Confusion Matrix:"
#                       y_test
# svm_binary_predictions    0    1
#                      0 5999  836
#                      1 1159 6322
# [1] "Accuracy: 0.860645431684828"
# [1] "Precision: 0.883207599888237"
# [1] "Recall: 0.845074187942788"

# %% [markdown]
# # Generalized Lasso

# %%
#create incidence matrix
D <- matrix(0, nrow = 2400-12, ncol = 2400)
for (i in 1:(2400-12)) {
  idx <- seq(i, 2400, by = 12)
  D[i, idx] <- 1
}
#print(D)

# %%
set.seed(123)

#add intercept term
X_train = cbind(1,X_train)
D <- cbind(matrix(0, nrow = nrow(D), ncol = 1), D)

#holding out 30% of X_train for validation
train_samples <- floor(0.7 * nrow(X_train))

# Create random indices for splitting the data
indices <- sample(nrow(X_train))

# Select indices for the training and validation sets
train_indices <- indices[1:train_samples]
val_indices <- indices[(train_samples + 1):nrow(X_train)]

# Split X_train and y_train into training and validation sets
X_train_train <- X_train[train_indices, ]
X_train_val <- X_train[val_indices, ]
y_train_train <- y_train[train_indices]
y_train_val <- y_train[val_indices]

X_train_train <- as.matrix(X_train_train)
X_train_val <- as.matrix(X_train_val)

# %%
#syntax:
model_gen<-genlasso(y_train_train, X_train_train, D)
summary(model_gen)
# Out:
# Warning message in genlasso(y_train_train, X_train_train, D):
# “Adding a small ridge penalty (multiplier 0.0001), because X has more columns than rows.”
#   df  lambda    rss
#   15  629747.58 1104253334
#   16  322492.92 1084303499
#   17  210851.75  324510225
#   18  183736.42  296916024
#   19  182630.43  364845052
#   20  181365.87  361159311
#   19  137798.27  249549855
#   20  136621.31  246955512
#   21  132772.30  237808489
#   22  123145.59  205837289
#   23  108353.44  161655092
#   24  104808.31  151613917
#   25   98971.73  135813783
#   26   98331.83  134144492
#   27   97116.15  131047998
#   28   96538.53  129557421
#   29   95741.03  127518513
#   30   75564.73  182503634
#   31   73818.78  174290621
#   32   72241.91  166863725
#   33   68363.07  149105402
#   34   64099.39  130604687
#   35   59388.51  112302296
#   36   59154.95  111411124
#   37   58572.54  109179948
#   38   56187.35   99851182
#   39   54127.15   92153921
#   40   53111.89   88441965
#   41   52100.77   84815291
#   42   51619.68   83101985
# ⋮ ⋮   ⋮         ⋮
#   989 0.2539470 2.997631
#   990 0.2537251 2.995884
#   991 0.2537222 2.995861
#   990 0.2530851 2.990801
#   989 0.2528341 2.988827
#   988 0.2523481 2.985014
#   989 0.2521509 2.983457
#   990 0.2517843 2.980561
#   991 0.2514331 2.977777
#   990 0.2509362 2.973944
#   991 0.2504227 2.969967
#   992 0.2503687 2.969549
#   993 0.2494836 2.962612
#   994 0.2484332 2.954267
#   995 0.2483159 2.953333
#   994 0.2482471 2.952794
#   993 0.2480698 2.951418
#   994 0.2474876 2.946891
#   993 0.2471259 2.944085
#   994 0.2456167 2.932342
#   995 0.2446721 2.925021
#   994 0.2438099 2.918428
#   995 0.2434825 2.915906
#   996 0.2432262 2.913925
#   997 0.2415023 2.900627
#   998 0.2413782 2.899672
#   997 0.2403446 2.891775
#   998 0.2401356 2.890175
#   999 0.2401108 2.889983
#   998 0.2397603 2.887274

# %%
lambda_values <- model_gen$lambda
plot(model_gen)
#plot(model_gen, lambda = lambda_values[lambda_values < 300000])
# Out:
# plot without title

# %%
prediction_matrix <- predict(model_gen, lambda = lambda_values[lambda_values < 300000])
#prediction_matrix$fit[prediction_matrix$fit < 0] <- 0
#prediction_matrix$fit[prediction_matrix$fit > 0] <- 1
fit_matrix <- prediction_matrix$fit
binary_predictions <- ifelse(fit_matrix > 0, 1, 0)

# %%
print(class(binary_predictions))
print(str(binary_predictions))
print(ncol(binary_predictions))
# Out:
# [1] "matrix" "array"
#  num [1:1114, 1:1998] 1 0 0 0 1 0 0 0 0 0 ...
#  - attr(*, "dimnames")=List of 2
#   ..$ : chr [1:1114] "14977" "139" "18079" "200" ...
#   ..$ : chr [1:1998] "210851.752" "183736.424" "182630.431" "181365.866" ...
# NULL
# [1] 1998

# %%
# Initialize vectors to store accuracy, precision, and recall for each lambda
accuracies <- numeric(ncol(binary_predictions))
precisions <- numeric(ncol(binary_predictions))
recalls <- numeric(ncol(binary_predictions))

# Iterate over columns (predictions for each lambda)
for (i in 1:ncol(binary_predictions)) {
    # Calculate accuracy for each lambda
    accuracies[i] <- sum(binary_predictions[, i] == y_train_train) / length(y_train_train)

    # Calculate true positives (TP), false positives (FP), and false negatives (FN)
    TP <- sum(binary_predictions[, i] == 1 & y_train_train == 1)
    FP <- sum(binary_predictions[, i] == 1 & y_train_train == 0)
    FN <- sum(binary_predictions[, i] == 0 & y_train_train == 1)

    # Calculate precision for each lambda
    precisions[i] <- TP / (TP + FP)

    # Calculate recall for each lambda
    recalls[i] <- TP / (TP + FN)
}

# %%
plot(accuracies)
plot(recalls)
plot(precisions)
# Out:
# plot without title
# plot without title
# plot without title

# %%
plot(accuracies[1000:1500])
plot(recalls[1000:1500])
plot(precisions[1000:1500])
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Validation set

# %%
prediction_matrix <- predict(model_gen, lambda = lambda_values[lambda_values < 300000], Xnew = X_train_val)
#prediction_matrix$fit[prediction_matrix$fit < 0] <- 0
#prediction_matrix$fit[prediction_matrix$fit > 0] <- 1
fit_matrix <- prediction_matrix$fit
binary_predictions_val <- ifelse(fit_matrix > 0, 1, 0)
#binary_predictions

# %%
# Initialize vectors to store accuracy, precision, and recall for each lambda
accuracies <- numeric(ncol(binary_predictions_val))
precisions <- numeric(ncol(binary_predictions_val))
recalls <- numeric(ncol(binary_predictions_val))

# Iterate over columns (predictions for each lambda)
for (i in 1:ncol(binary_predictions_val)) {
    # Calculate accuracy for each lambda
    accuracies[i] <- sum(binary_predictions_val[, i] == y_train_val) / length(y_train_val)

    # Calculate true positives (TP), false positives (FP), and false negatives (FN)
    TP <- sum(binary_predictions_val[, i] == 1 & y_train_val == 1)
    FP <- sum(binary_predictions_val[, i] == 1 & y_train_val == 0)
    FN <- sum(binary_predictions_val[, i] == 0 & y_train_val == 1)

    # Calculate precision for each lambda
    precisions[i] <- TP / (TP + FP)

    # Calculate recall for each lambda
    recalls[i] <- TP / (TP + FN)
}

# %%
plot(accuracies)
plot(recalls)
plot(precisions)
# Out:
# plot without title
# plot without title
# plot without title

# %%
plot(accuracies[1000:1500])
plot(recalls[1000:1500])
plot(precisions[1000:1500])
# Out:
# plot without title
# plot without title
# plot without title

# %%
index_of_max_accuracy <- which.max(accuracies)
lambda_restricted = lambda_values[lambda_values < 300000]
best_lambda = lambda_restricted[index_of_max_accuracy]
best_lambda
accuracies[index_of_max_accuracy]
# Out:
# [1] 9.630267
# [1] 0.7050209

# %%
index_of_max_accuracy <- which.max(accuracies)
lambda_restricted = lambda_values[lambda_values < 300000]
best_lambda = lambda_restricted[index_of_max_accuracy]

# Retrieve corresponding recall and precision values
best_recall = recalls[index_of_max_accuracy]
best_precision = precisions[index_of_max_accuracy]

# Print results
cat("Best Lambda:", best_lambda, "\n")
cat("Accuracy:", accuracies[index_of_max_accuracy], "\n")
cat("Recall:", best_recall, "\n")
cat("Precision:", best_precision, "\n")
# Out:
# Best Lambda: 9.630267
# Accuracy: 0.7050209
# Recall: 0.9506173
# Precision: 0.6416667
